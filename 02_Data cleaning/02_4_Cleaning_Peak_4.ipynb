# %%
import datetime as datetime
from IPython.display import display
import matplotlib.pyplot as plt
from matplotlib.pyplot import text
# %matplotlib inline
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import TweetTokenizer
import numpy as np
import pandas as pd
plt.style.use("bmh")
plt.rcParams['figure.figsize'] = (10, 5)
import re
from sklearn.feature_extraction.text import CountVectorizer
from string import punctuation

# %% [markdown]
# ## Loading DataFrames

# %%
udf = pd.read_pickle('Your/Data/Path/tweaked_user_dataframe.pkl')
udf
# Out:
#                                             location                   id  \
# 0                             Waiyaki Way, Westlands   697374646614781952
# 1                                                NaN             87371572
# 2                          Anglican Communion Office            903497472
# 3                                               Rome            761714520
# 4                                     Nairobi, Kenya  1020255964044328961
# ..                                               ...                  ...
# 166                                  Federal Way, WA             11859822
# 164                       Plot 15B Nakasero, Kampala            759998299
# 167                                   Dakar, Senegal            830807449
# 157                            Addis Ababa, Ethiopia           2231308272
# 171  27 St Patricks Road, Hatfield\nHarare\nZimbabwe           2193947323
#
#                              name  verified  public_metrics.followers_count  \
# 0                       AACC-CETA     False                            1565
# 1                            ACNA     False                            9023
# 2               Anglican Alliance     False                            2291
# 3            Anglican Centre Rome     False                            2681
# 4        Anglican Church of Kenya     False                            1095
# ..                            ...       ...                             ...
# 166              World Vision USA      True                          554386
# 164           World Vision Uganda     False                            4278
# 167      World Vision West Africa     False                            2245
# 157          WorldVision Ethiopia     False                            1958
# 171  Zimbabwe Council of Churches     False                            5834
#
#      public_metrics.following_count  public_metrics.tweet_count  \
# 0                               666                        2795
# 1                              1796                        3393
# 2                              1195                        3599
# 3                               839                        1733
# 4                               185                         567
# ..                              ...                         ...
# 166                           14283                       92602
# 164                             580                        3375
# 167                             563                        2088
# 157                             178                         420
# 171                             522                        2462
#
#             country
# 0             Kenya
# 1               NaN
# 2    United Kingdom
# 3            Italia
# 4             Kenya
# ..              ...
# 166   United States
# 164          Uganda
# 167         Sénégal
# 157           ኢትዮጵያ
# 171        Zimbabwe
#
# [126 rows x 8 columns]

# %%
df = pd.read_pickle('Your/Data/Path/tweet_dataframe_p3.pkl')
df
# Out:
#                  author_id                                               text  \
# 0       697374646614781952  RT @AWalkerSmith7: @AaccCeta @ArchbishopSapit ...
# 1       697374646614781952  RT @sceptwic: Another important step in road t...
# 2       697374646614781952  Congratulations Ven Rose Okeno ACK Diocese of ...
# 3       697374646614781952  Consecration Service of Ven Rose Okeno ACK Dio...
# 4       697374646614781952  We are looking forward to today’s Consecration...
# ...                    ...                                                ...
# 308837          2193947323  In our New Year Message to the Nation we proff...
# 308838          2193947323  RT @NewsDayZimbabwe: THE @zccinzim has launche...
# 308839          2193947323  We can choose the route of engagement or that ...
# 308840          2193947323  For many Zimbabweans, 2019 has come amidst muc...
# 308841          2193947323  “From a position of reason, our problems seem ...
#
#        lang                                  referenced_tweets reply_settings  \
# 0        en  [{'type': 'retweeted', 'id': '1437029861676228...       everyone
# 1        en  [{'type': 'retweeted', 'id': '1437043141979295...       everyone
# 2        en                                                NaN       everyone
# 3        en                                                NaN       everyone
# 4        en  [{'type': 'replied_to', 'id': '143695708915549...       everyone
# ...     ...                                                ...            ...
# 308837   en  [{'type': 'quoted', 'id': '1082850893807144962'}]       everyone
# 308838   en  [{'type': 'retweeted', 'id': '1082932233500065...       everyone
# 308839   en                                                NaN       everyone
# 308840   en                                                NaN       everyone
# 308841   en                                                NaN       everyone
#
#             conversation_id                   id                created_at  \
# 0       1437051433480753156  1437051433480753156 2021-09-12 13:52:15+00:00
# 1       1437051325255192582  1437051325255192582 2021-09-12 13:51:49+00:00
# 2       1436979065114800131  1436979065114800131 2021-09-12 09:04:41+00:00
# 3       1436975615480041473  1436975615480041473 2021-09-12 08:50:59+00:00
# 4       1436957089155493889  1436957092787757056 2021-09-12 07:37:22+00:00
# ...                     ...                  ...                       ...
# 308837  1082937561537044480  1082937561537044480 2019-01-09 09:50:09+00:00
# 308838  1082934512777117696  1082934512777117696 2019-01-09 09:38:02+00:00
# 308839  1082904479526240256  1082904479526240256 2019-01-09 07:38:41+00:00
# 308840  1082548265617371137  1082548265617371137 2019-01-08 08:03:13+00:00
# 308841  1082339383217393666  1082339383217393666 2019-01-07 18:13:12+00:00
#
#                                         entities.mentions  \
# 0       [{'start': 3, 'end': 17, 'username': 'AWalkerS...
# 1       [{'start': 3, 'end': 12, 'username': 'sceptwic...
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 308837                                                NaN
# 308838  [{'start': 3, 'end': 19, 'username': 'NewsDayZ...
# 308839  [{'start': 211, 'end': 227, 'username': 'NewsD...
# 308840  [{'start': 187, 'end': 199, 'username': 'EFZZI...
# 308841  [{'start': 148, 'end': 161, 'username': 'kenne...
#
#                                      entities.annotations  ...  \
# 0       [{'start': 93, 'end': 95, 'probability': 0.919...  ...
# 1                                                     NaN  ...
# 2       [{'start': 16, 'end': 29, 'probability': 0.516...  ...
# 3       [{'start': 124, 'end': 147, 'probability': 0.5...  ...
# 4       [{'start': 116, 'end': 124, 'probability': 0.6...  ...
# ...                                                   ...  ...
# 308837                                                NaN  ...
# 308838                                                NaN  ...
# 308839                                                NaN  ...
# 308840                                                NaN  ...
# 308841  [{'start': 137, 'end': 142, 'probability': 0.7...  ...
#
#                                             entities.urls  \
# 0                                                     NaN
# 1                                                     NaN
# 2       [{'start': 213, 'end': 236, 'url': 'https://t....
# 3       [{'start': 239, 'end': 262, 'url': 'https://t....
# 4                                                     NaN
# ...                                                   ...
# 308837  [{'start': 271, 'end': 294, 'url': 'https://t....
# 308838                                                NaN
# 308839  [{'start': 183, 'end': 206, 'url': 'https://t....
# 308840  [{'start': 264, 'end': 287, 'url': 'https://t....
# 308841  [{'start': 211, 'end': 234, 'url': 'https://t....
#
#         in_reply_to_user_id  geo.place_id  geo.coordinates.type  \
# 0                       NaN           NaN                   NaN
# 1                       NaN           NaN                   NaN
# 2                       NaN           NaN                   NaN
# 3                       NaN           NaN                   NaN
# 4        697374646614781952           NaN                   NaN
# ...                     ...           ...                   ...
# 308837                  NaN           NaN                   NaN
# 308838                  NaN           NaN                   NaN
# 308839                  NaN           NaN                   NaN
# 308840                  NaN           NaN                   NaN
# 308841                  NaN           NaN                   NaN
#
#        geo.coordinates.coordinates withheld.copyright withheld.country_codes  \
# 0                              NaN                NaN                    NaN
# 1                              NaN                NaN                    NaN
# 2                              NaN                NaN                    NaN
# 3                              NaN                NaN                    NaN
# 4                              NaN                NaN                    NaN
# ...                            ...                ...                    ...
# 308837                         NaN                NaN                    NaN
# 308838                         NaN                NaN                    NaN
# 308839                         NaN                NaN                    NaN
# 308840                         NaN                NaN                    NaN
# 308841                         NaN                NaN                    NaN
#
#        withheld.scope entities.cashtags  \
# 0                 NaN               NaN
# 1                 NaN               NaN
# 2                 NaN               NaN
# 3                 NaN               NaN
# 4                 NaN               NaN
# ...               ...               ...
# 308837            NaN               NaN
# 308838            NaN               NaN
# 308839            NaN               NaN
# 308840            NaN               NaN
# 308841            NaN               NaN
#
#                                            text_processed
# 0       [thanking, god, historic, moment, church, hist...
# 1       [another, important, step, road, #justicedigni...
# 2       [congratulations, ven, rose, okeno, ack, dioce...
# 3       [consecration, service, ven, rose, okeno, ack,...
# 4       [looking, forward, today, consecration, enthro...
# ...                                                   ...
# 308837  [new, year, message, nation, proffered, areas,...
# 308838  [launched, fresh, bid, broker, dialogue, presi...
# 308839  [choose, route, engagement, conflict, route, i...
# 308840  [many, zimbabweans, come, amidst, much, hardsh...
# 308841  [position, reason, problems, seem, political, ...
#
# [265221 rows x 25 columns]

# %% [markdown]
# ## Cleanup

# %%
# Functions
# --- Drop columns not needed for analysis from tweet DataFrame
def clean_tweet(df):
    return (df
           .drop(columns=[c for c in df.columns if 'entities.cashtags' in c])
           .drop(columns=['id', 'lang', 'in_reply_to_user_id', 'conversation_id',
                          'public_metrics.retweet_count', 'public_metrics.reply_count',
                          'public_metrics.like_count', 'public_metrics.quote_count',
                          'entities.urls',
                          'geo.place_id', 'geo.coordinates.type', 'geo.coordinates.coordinates', 
                          'withheld.copyright', 'withheld.country_codes', 'withheld.scope', 'reply_settings'])
                          )

# --- Modify tweet DataFrame to add new columns needed for analysis
def modify_tweet(df):
    return (clean_tweet(df)
                .assign(is_reply=df['text'].str.startswith('@'),
                   referenced_type=df['referenced_tweets'].apply(lambda t: t[0]['type'] if isinstance(t, list) else np.nan),
                   length=lambda df_:df_.text.str.len(),
                   tweet_count=1,
                   created_truncated=df['created_at'].apply(lambda d: datetime.date(d.year, d.month, d.day)),
                  )
           )

# --- merge modified tweet and user DataFrames
def create_analysis_frame(df1, df2):
    return(modify_tweet(df1)
            .merge(df2, left_on='author_id', right_on='id', how='left')
            .drop(columns = ['id', 'referenced_tweets', 'verified', 'location',
                                'public_metrics.following_count', 'public_metrics.tweet_count'])
            )

# Main
tdf = create_analysis_frame(df, udf)

with pd.option_context('display.max_colwidth', 280):
    display(tdf)
# Out:
#                  author_id  \
# 0       697374646614781952
# 1       697374646614781952
# 2       697374646614781952
# 3       697374646614781952
# 4       697374646614781952
# ...                    ...
# 265216          2193947323
# 265217          2193947323
# 265218          2193947323
# 265219          2193947323
# 265220          2193947323
#
#                                                                                                                                                                                                                                                                                            text  \
# 0       RT @AWalkerSmith7: @AaccCeta @ArchbishopSapit @LesmoreGEzkiel @DrMwaniki @fmwombeki Thanking God 4 this historic moment n church history n Kenya! 2 God b the glory! Ashe! Amen! @Oikoumene @AaccCeta @AdNAUbuntu @JaCouncilChurch @ncccusa @iamepiscopalian @GETIWCC @WCCpaween @An...
# 1                                                                                   RT @sceptwic: Another important step in road to #JusticeDignitySolidarity. Kenyan churches leading the way it seems as number of women in #episcopate rises again. @ACK @full_kenya https://t.co/CAPRZdimkq
# 2                                                  Congratulations Ven Rose Okeno ACK Diocese of Butere. The first Woman Diocesan Bishop in the history of the Anglican Church of Kenya.  We thank God for the new chapters being written in the history of the Church. https://t.co/6Up7M3cEsb
# 3                        Consecration Service of Ven Rose Okeno ACK Diocese of Butere. She is the first Woman Diocesan  Bishop in the history of the Anglican Church of Kenya.  New chapters being written in the history of the Church. We thank God for such moments. https://t.co/hzkus3byb5
# 4                                                                                                                                                    We are looking forward to today’s Consecration and Enthronement of the first Woman Bishop in The Anglican Church of Kenya Ven. Rose Okeno.
# ...                                                                                                                                                                                                                                                                                         ...
# 265216  In our New Year Message to the Nation we proffered 4 areas that need to be address to avert the possible catastrophe prophesied in Luke 19:44. There is definitely need to forge a renewed national vision and create a just social contract between the rulers and the ruled. https...
# 265217  RT @NewsDayZimbabwe: THE @zccinzim has launched a fresh bid to broker dialogue between President @edmnangagwa and MDC leader @nelsonchamisa in order to end the worsening economic crisis in the country that has been characterised by a serious currency mess&amp; massive price h...
# 265218  We can choose the route of engagement or that of conflict, route of individual solutions or that of a shared vision, route that entrenches greed or one that leads to the common good\n\nhttps://t.co/khQ5mOHxuj via @NewsDayZimbabwe\n\n@edmnangagwa @nelsonchamisa @BitiTendai @In...
# 265219  For many Zimbabweans, 2019 has come amidst much hardship and uncertainty. Many wonder whether the current times signify birth pains or throes.\n\nHere is our New Year Message to the Nation\n@EFZZIMBABWE @InfoMinZW @ZBCNewsonline @263Chat @StarFMNews @powerfmzimbabwe https://t...
# 265220  “From a position of reason, our problems seem political &amp; economical but frm a position of revelation, w have a deep theological crisis” Rev Dr @kennethmtata on #MinistersDeskZW\nWatch e full interview on FB https://t.co/i5gHT455i4\n@263Chat @OpenParlyZw @OpenSpaceZW @Shi...
#
#                       created_at  \
# 0      2021-09-12 13:52:15+00:00
# 1      2021-09-12 13:51:49+00:00
# 2      2021-09-12 09:04:41+00:00
# 3      2021-09-12 08:50:59+00:00
# 4      2021-09-12 07:37:22+00:00
# ...                          ...
# 265216 2019-01-09 09:50:09+00:00
# 265217 2019-01-09 09:38:02+00:00
# 265218 2019-01-09 07:38:41+00:00
# 265219 2019-01-08 08:03:13+00:00
# 265220 2019-01-07 18:13:12+00:00
#
#                                                                                                                                                                                                                                                                               entities.mentions  \
# 0       [{'start': 3, 'end': 17, 'username': 'AWalkerSmith7', 'id': '1868363888'}, {'start': 19, 'end': 28, 'username': 'AaccCeta', 'id': '697374646614781952'}, {'start': 29, 'end': 45, 'username': 'ArchbishopSapit', 'id': '798412484742959105'}, {'start': 46, 'end': 61, 'username': '...
# 1                                                                                                                                                                                                                           [{'start': 3, 'end': 12, 'username': 'sceptwic', 'id': '35702398'}]
# 2                                                                                                                                                                                                                                                                                           NaN
# 3                                                                                                                                                                                                                                                                                           NaN
# 4                                                                                                                                                                                                                                                                                           NaN
# ...                                                                                                                                                                                                                                                                                         ...
# 265216                                                                                                                                                                                                                                                                                      NaN
# 265217  [{'start': 3, 'end': 19, 'username': 'NewsDayZimbabwe', 'id': '123875667'}, {'start': 25, 'end': 34, 'username': 'zccinzim', 'id': '2193947323'}, {'start': 97, 'end': 109, 'username': 'edmnangagwa', 'id': '447895686'}, {'start': 125, 'end': 139, 'username': 'nelsonchamisa', '...
# 265218  [{'start': 211, 'end': 227, 'username': 'NewsDayZimbabwe', 'id': '123875667'}, {'start': 229, 'end': 241, 'username': 'edmnangagwa', 'id': '447895686'}, {'start': 242, 'end': 256, 'username': 'nelsonchamisa', 'id': '192100065'}, {'start': 257, 'end': 268, 'username': 'BitiTen...
# 265219  [{'start': 187, 'end': 199, 'username': 'EFZZIMBABWE', 'id': '910786494255820800'}, {'start': 200, 'end': 210, 'username': 'InfoMinZW', 'id': '1047163274951905280'}, {'start': 211, 'end': 225, 'username': 'ZBCNewsonline', 'id': '726133273'}, {'start': 226, 'end': 234, 'userna...
# 265220  [{'start': 148, 'end': 161, 'username': 'kennethmtata', 'id': '153173718'}, {'start': 235, 'end': 243, 'username': '263Chat', 'id': '892792496'}, {'start': 244, 'end': 256, 'username': 'OpenParlyZw', 'id': '4156551377'}, {'start': 257, 'end': 269, 'username': 'OpenSpaceZW', '...
#
#                                                                                                                                                                                                                                                                            entities.annotations  \
# 0                                                                                                                                                                                                  [{'start': 93, 'end': 95, 'probability': 0.9196, 'type': 'Other', 'normalized_text': 'God'}]
# 1                                                                                                                                                                                                                                                                                           NaN
# 2       [{'start': 16, 'end': 29, 'probability': 0.5163, 'type': 'Person', 'normalized_text': 'Ven Rose Okeno'}, {'start': 108, 'end': 131, 'probability': 0.5879, 'type': 'Place', 'normalized_text': 'Anglican Church of Kenya'}, {'start': 144, 'end': 146, 'probability': 0.976, 'type':...
# 3                                                                             [{'start': 124, 'end': 147, 'probability': 0.5667, 'type': 'Place', 'normalized_text': 'Anglican Church of Kenya'}, {'start': 217, 'end': 219, 'probability': 0.9677, 'type': 'Other', 'normalized_text': 'God'}]
# 4                                                                                    [{'start': 116, 'end': 124, 'probability': 0.6155, 'type': 'Place', 'normalized_text': 'Kenya Ven'}, {'start': 127, 'end': 136, 'probability': 0.8553, 'type': 'Person', 'normalized_text': 'Rose Okeno'}]
# ...                                                                                                                                                                                                                                                                                         ...
# 265216                                                                                                                                                                                                                                                                                      NaN
# 265217                                                                                                                                                                                                                                                                                      NaN
# 265218                                                                                                                                                                                                                                                                                      NaN
# 265219                                                                                                                                                                                                                                                                                      NaN
# 265220                                                                                                                                                                                       [{'start': 137, 'end': 142, 'probability': 0.7207, 'type': 'Person', 'normalized_text': 'Rev Dr'}]
#
#                                                     entities.hashtags  \
# 0                                                                 NaN
# 1       [{'start': 48, 'end': 73, 'tag': 'JusticeDignitySolidarity'}]
# 2                                                                 NaN
# 3                                                                 NaN
# 4                                                                 NaN
# ...                                                               ...
# 265216                                                            NaN
# 265217                                                            NaN
# 265218                                                            NaN
# 265219                                                            NaN
# 265220         [{'start': 165, 'end': 181, 'tag': 'MinistersDeskZW'}]
#
#                                                                                                                                                                                                              text_processed  \
# 0                                                                                                                                         [thanking, god, historic, moment, church, history, kenya, god, glory, ashe, amen]
# 1                                                                            [another, important, step, road, #justicedignitysolidarity, kenyan, churches, leading, way, seems, number, women, #episcopate, rises, <-url->]
# 2                                 [congratulations, ven, rose, okeno, ack, diocese, butere, first, woman, diocesan, bishop, history, anglican, church, kenya, thank, god, new, chapters, written, history, church, <-url->]
# 3                  [consecration, service, ven, rose, okeno, ack, diocese, butere, first, woman, diocesan, bishop, history, anglican, church, kenya, new, chapters, written, history, church, thank, god, moments, <-url->]
# 4                                                                                                    [looking, forward, today, consecration, enthronement, first, woman, bishop, anglican, church, kenya, ven, rose, okeno]
# ...                                                                                                                                                                                                                     ...
# 265216  [new, year, message, nation, proffered, areas, need, address, avert, possible, catastrophe, prophesied, luke, definitely, need, forge, renewed, national, vision, create, social, contract, rulers, ruled, <-url->]
# 265217                         [launched, fresh, bid, broker, dialogue, president, mdc, leader, order, end, worsening, economic, crisis, country, characterised, serious, currency, mess, massive, price, <-url->, <-url->]
# 265218                                                                [choose, route, engagement, conflict, route, individual, solutions, shared, vision, route, entrenches, greed, one, leads, common, good, <-url->, via]
# 265219                                            [many, zimbabweans, come, amidst, much, hardship, uncertainty, many, wonder, whether, current, times, signify, birth, pains, throes, new, year, message, nation, <-url->]
# 265220                                     [position, reason, problems, seem, political, economical, frm, position, revelation, deep, theological, crisis, rev, #ministersdeskzw, watch, full, interview, <-url->, <-url->]
#
#         is_reply referenced_type  length  tweet_count created_truncated  \
# 0          False       retweeted     363            1        2021-09-12
# 1          False       retweeted     203            1        2021-09-12
# 2          False             NaN     236            1        2021-09-12
# 3          False             NaN     262            1        2021-09-12
# 4          False      replied_to     138            1        2021-09-12
# ...          ...             ...     ...          ...               ...
# 265216     False          quoted     294            1        2019-01-09
# 265217     False       retweeted     304            1        2019-01-09
# 265218     False             NaN     279            1        2019-01-09
# 265219     False             NaN     287            1        2019-01-08
# 265220     False             NaN     308            1        2019-01-07
#
#                                 name  public_metrics.followers_count   country
# 0                          AACC-CETA                            1565     Kenya
# 1                          AACC-CETA                            1565     Kenya
# 2                          AACC-CETA                            1565     Kenya
# 3                          AACC-CETA                            1565     Kenya
# 4                          AACC-CETA                            1565     Kenya
# ...                              ...                             ...       ...
# 265216  Zimbabwe Council of Churches                            5834  Zimbabwe
# 265217  Zimbabwe Council of Churches                            5834  Zimbabwe
# 265218  Zimbabwe Council of Churches                            5834  Zimbabwe
# 265219  Zimbabwe Council of Churches                            5834  Zimbabwe
# 265220  Zimbabwe Council of Churches                            5834  Zimbabwe
#
# [265221 rows x 15 columns]

# %%
def tweet_counter(df):
    return (df
            .set_index('created_at')
            .sort_index()
            .tweet_count
            .resample('d')
            .sum()
            .rename('counts')
            .to_frame()
           )

# %%
def median_abs_dev(df, constant=None):
    if constant is None:
        # allows us to use the MAD to roughly approximate to the standard deviation
        # see the wikipedia page
        constant = 1.4826
    return constant * np.median(np.abs((df - np.median(df))))


def mad_normalize(df, constant=None):
    # puts this dataframe into multiples of the MAD, similar to Zscoring
    # abs(x - median(x)) / MAD(df)
    return (df
             .sub(np.median(df))
             .pipe(np.abs)
             .div(median_abs_dev(df)))

# %%
def top_dates(df):
    return (df
             .pipe(np.log)
             .diff()
             .dropna()
             .pipe(mad_normalize)
             .sort_values(by="counts", ascending=False)
             .head()
             .index
             .values
            )

# %%
TWEET_TOKENIZER = TweetTokenizer(preserve_case=False,
                                 strip_handles=True, reduce_len=False)
STOPWORDS = (set(nltk.corpus.stopwords.words("english")) |
             {"...", '…', '•', '’', "com"} |
             set(punctuation))

def replace_urls(string, replacement=None):
    if replacement is None:
        replacement = "<-URL->"
    pattern = re.compile('(https?://)?(\w*[.]\w+)+([/?=&]+\w+)*')
    return re.sub(pattern, replacement, string)

def tokenizer(tweet_text, custom_words=None):
    text = (replace_urls(tweet_text))
    tokens = TWEET_TOKENIZER.tokenize(text.lower())
    tokens = (token for token in tokens if token not in punctuation)
    tokens = (token for token in tokens if token.islower())
    tokens = (token for token in tokens if token not in STOPWORDS)
    tokens = (token for token in tokens if len(token) >= 3)
    if custom_words:
        tokens = (token for token in tokens if token not in custom_words)
    return list(tokens)

def get_frequent_terms(text_series, stop_words=None, ngram_range=None):
    if ngram_range is None:
        ngram_range = (1, 3)
    '''
    Input:
       text_series: a list or series of documents
       stop_words: a list of stop_words to ignore, or the string 'english',
                   which uses a built-in stop word list for the english language.
                   By default, there are no stop words used
       ngram_range: a single int, or a 2 tuple representing the range of ngrams to count.
                    the default (1,2) counts 1- and 2- grams.
    Returns:
       a dataframe of counts, indexed by n-gram
    '''
    count_vectorizer = CountVectorizer(analyzer = "word",
                                       tokenizer = tokenizer,
                                       stop_words = stop_words, # try changing the stopword sets that we use.
                                                                # notice that many top terms are words like
                                                                # "and" and "the"
                                       ngram_range = ngram_range # you can change this to count frequencies of
                                                           # ngrams as well as single tokens
                                                           # a range of (1,2) counts 1-grams (single tokens) and
                                                           # 2-grams (2-token phrases)
                                      )
    term_freq_matrix = count_vectorizer.fit_transform(text_series)
    terms = count_vectorizer.get_feature_names()
    term_frequencies = term_freq_matrix.sum(axis = 0).tolist()[0]

    term_freq_df = (pd.DataFrame(list(zip(terms, term_frequencies)), columns = ["token","count"])
                    .set_index("token")
                    .sort_values("count",ascending = False))
    return term_freq_df

# %% [markdown]
# ## Communication Volume

# %%
# Create DataFrame with tweets/day
ddf =(tdf
      .set_index('created_at')
      .sort_index()
      .tweet_count
      .resample('d')
      .sum()
      .rename('counts')
      .to_frame()
     )
ddf
# Out:
#                            counts
# created_at
# 2019-01-01 00:00:00+00:00     123
# 2019-01-02 00:00:00+00:00     182
# 2019-01-03 00:00:00+00:00     213
# 2019-01-04 00:00:00+00:00     206
# 2019-01-05 00:00:00+00:00      98
# ...                           ...
# 2021-09-08 00:00:00+00:00     204
# 2021-09-09 00:00:00+00:00     190
# 2021-09-10 00:00:00+00:00     215
# 2021-09-11 00:00:00+00:00      96
# 2021-09-12 00:00:00+00:00      75
#
# [986 rows x 1 columns]

# %%
# Plot tweets/day
fig, ax = plt.subplots(figsize=(15,5))
(ddf
 .plot(ax=ax)
)
# Out:
# <AxesSubplot:xlabel='created_at'>

# %%
# Plot tweets/week
fig, ax = plt.subplots(figsize=(15,5))
(ddf
 .resample('w')
 .mean()
 .plot(ax=ax)
)
# Out:
# <AxesSubplot:xlabel='created_at'>

# %% [markdown]
# ##### Gesamtkommunikationsvolumen

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize = (10, 5))
fig.tight_layout()
(ddf 
 .rolling(7) # rolling(7) instead of resample(w) to keep weekend dips visible
 .mean()
 .rename(columns={"counts": "1W SMA"})
 .plot(ax=axes)
)

axes.set_xlabel('Date')
axes.set_ylabel('Number of Tweets')
axes.set_title('Simple Moving Average of Number of Tweets')
# Out:
# Text(0.5, 1.0, 'Gleitender Mittelwert der täglichen Tweets')

# %% [markdown]
# ##### Peak 4 - Zomm in on timeframe

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize = (15, 5))
fig.tight_layout()
(ddf
 .loc[(ddf.index >= '2019-12-01') &
      (ddf.index < '2020-01-20')]
 .rolling(7)
 .mean()
 .rename(columns={"counts": "1W SMA"})
 .plot(ax=axes)
)

axes.set_xlabel('Date')
axes.set_ylabel('Number of Tweets')
axes.set_title('Moving average of Tweets/Day')
# Out:
# Text(0.5, 1.0, 'Gleitender Mittelwert der täglichen Tweets')

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize = (15, 5))
fig.tight_layout()
(ddf
 .loc[(ddf.index >= '2019-12-25') &
      (ddf.index < '2020-01-10')]
 .rename(columns={"counts": "1W SMA"})
 .plot(ax=axes)
)

axes.set_xlabel('Date')
axes.set_ylabel('Number of Tweets')
axes.set_title('Moving average of Tweets/Day')
# Out:
# Text(0.5, 1.0, 'Gleitender Mittelwert der täglichen Tweets')

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize = (15, 5))
fig.tight_layout()
(ddf
 .loc[(ddf.index >= '2019-12-29') &
      (ddf.index < '2020-01-01')]
 .rename(columns={"counts": "1W SMA"})
 .plot(ax=axes)
)

axes.set_xlabel('Date')
axes.set_ylabel('Number of Tweets')
axes.set_title('Moving average of Tweets/Day')
# Out:
# Text(0.5, 1.0, 'Gleitender Mittelwert der täglichen Tweets')

# %%
ndf = tdf[(tdf['created_at'] >= '2019-12-30') & (tdf['created_at'] < '2019-12-31')]
ndf
# Out:
#                  author_id                                               text  \
# 1949             761714520  RT @RomanAnglican: The fifth and final chapter...
# 4503            2301602804  Today in the #AnglicanCycleofPrayer we remembe...
# 9905    858032746458783744  @seaofcomplicity @sallyBarnes3 @BishopNewcastl...
# 9906    858032746458783744  RT @seaofcomplicity: The stories about Ball an...
# 9907    858032746458783744  @sallyBarnes3 @seaofcomplicity Unless, the C o...
# ...                    ...                                                ...
# 256827            11859822  DYK? Extreme poverty is decreasing. Fewer kids...
# 261778            14086764  Three months on from Tropical Cyclone PODUL an...
# 261779            14086764  RT @WVSouthSudan: Today marks the 15th year of...
# 261780            14086764  (3/3) Last year, 5 million people learned abou...
# 261781            14086764  (2/3) She and her classmates were introduced t...
#
#                       created_at  \
# 1949   2019-12-30 21:29:11+00:00
# 4503   2019-12-30 08:00:56+00:00
# 9905   2019-12-30 12:48:50+00:00
# 9906   2019-12-30 12:37:31+00:00
# 9907   2019-12-30 12:36:20+00:00
# ...                          ...
# 256827 2019-12-30 00:47:01+00:00
# 261778 2019-12-30 21:01:03+00:00
# 261779 2019-12-30 19:04:01+00:00
# 261780 2019-12-30 15:52:06+00:00
# 261781 2019-12-30 15:51:41+00:00
#
#                                         entities.mentions  \
# 1949    [{'start': 3, 'end': 17, 'username': 'RomanAng...
# 4503                                                  NaN
# 9905    [{'start': 0, 'end': 16, 'username': 'seaofcom...
# 9906    [{'start': 3, 'end': 19, 'username': 'seaofcom...
# 9907    [{'start': 0, 'end': 13, 'username': 'sallyBar...
# ...                                                   ...
# 256827                                                NaN
# 261778                                                NaN
# 261779  [{'start': 3, 'end': 16, 'username': 'WVSouthS...
# 261780                                                NaN
# 261781                                                NaN
#
#                                      entities.annotations  \
# 1949    [{'start': 91, 'end': 94, 'probability': 0.934...
# 4503    [{'start': 74, 'end': 79, 'probability': 0.993...
# 9905                                                  NaN
# 9906    [{'start': 39, 'end': 42, 'probability': 0.914...
# 9907                                                  NaN
# ...                                                   ...
# 256827  [{'start': 94, 'end': 96, 'probability': 0.981...
# 261778  [{'start': 76, 'end': 87, 'probability': 0.514...
# 261779                                                NaN
# 261780                                                NaN
# 261781                                                NaN
#
#                                         entities.hashtags  \
# 1949                                                  NaN
# 4503    [{'start': 13, 'end': 35, 'tag': 'AnglicanCycl...
# 9905                                                  NaN
# 9906                                                  NaN
# 9907                                                  NaN
# ...                                                   ...
# 256827  [{'start': 164, 'end': 175, 'tag': 'WVAdvocacy'}]
# 261778                                                NaN
# 261779  [{'start': 52, 'end': 64, 'tag': 'AsiaTsunami'...
# 261780                                                NaN
# 261781                                                NaN
#
#                                            text_processed  is_reply  \
# 1949    [fifth, final, chapter, history, anglican, com...     False
# 4503    [today, #anglicancycleofprayer, remember, dioc...     False
# 9905    [true, women, colour, still, included, debates...      True
# 9906    [stories, ball, fletcher, proved, much, instit...     False
# 9907    [unless, becomes, transparent, see, cases, hus...      True
# ...                                                   ...       ...
# 256827  [dyk, extreme, poverty, decreasing, fewer, kid...     False
# 261778  [three, months, tropical, cyclone, podul, trop...     False
# 261779  [today, marks, 15th, year, #asiatsunami, broug...     False
# 261780  [last, year, million, people, learned, importa...     False
# 261781  [classmates, introduced, handwashing, cleaning...     False
#
#        referenced_type  length  tweet_count created_truncated  \
# 1949         retweeted     235            1        2019-12-30
# 4503               NaN     213            1        2019-12-30
# 9905        replied_to     330            1        2019-12-30
# 9906         retweeted     253            1        2019-12-30
# 9907        replied_to     207            1        2019-12-30
# ...                ...     ...          ...               ...
# 256827             NaN     199            1        2019-12-30
# 261778             NaN     223            1        2019-12-30
# 261779       retweeted     314            1        2019-12-30
# 261780      replied_to     147            1        2019-12-30
# 261781      replied_to     188            1        2019-12-30
#
#                         name  public_metrics.followers_count        country
# 1949    Anglican Centre Rome                            2681         Italia
# 4503      Anglican Communion                            3683            NaN
# 9905          BAME Anglican.                            4379             日本
# 9906          BAME Anglican.                            4379             日本
# 9907          BAME Anglican.                            4379             日本
# ...                      ...                             ...            ...
# 256827      World Vision USA                          554386  United States
# 261778          World Vision                         1112426            NaN
# 261779          World Vision                         1112426            NaN
# 261780          World Vision                         1112426            NaN
# 261781          World Vision                         1112426            NaN
#
# [22363 rows x 15 columns]

# %% [markdown]
# ##### Peak 4 - Check for most frequently used words

# %%
top_dates(tweet_counter(ndf))
# Out:
# array(['2019-11-23T00:00:00.000000000', '2019-11-30T00:00:00.000000000',
#        '2019-11-29T00:00:00.000000000', '2019-11-25T00:00:00.000000000',
#        '2019-11-24T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
get_frequent_terms(ndf['text']).head(15)
# Out:
#                   count
# token
# <-url->           22377
# new               22229
# year              22229
# help              22219
# gift              22217
# new year          22217
# future            22214
# giving            22214
# full              22214
# kids              22214
# almost            22213
# ring              22213
# gift <-url->      22213
# choices           22212
# year almost help  22212

# %%
(ndf
 .groupby('author_id')
 .agg({'tweet_count': 'count', 'name': 'last','country': 'last'})
 .sort_values('tweet_count',ascending = False)
 .reset_index(drop=True)
 .rename(columns={'tweet_count': 'Tweets', 'name': 'Nutzername', 'country': 'Land'})
)
# Out:
#     Tweets                                        Nutzername  \
# 0    22218                                  World Vision USA
# 1       12                                Interfaith Matters
# 2       11                              Church & Society UMC
# 3        9                                               CWS
# 4        8                          Compassion International
# 5        8                                    BAME Anglican.
# 6        7                                      Faiths Forum
# 7        7                   International Christian Concern
# 8        7                               Bread for the World
# 9        7                                     ELCA Advocacy
# 10       6                              Presbyterian Outlook
# 11       6                                            CSW_UK
# 12       5                                         GFA World
# 13       4                                      World Vision
# 14       4                          The Faith & Belief Forum
# 15       3                                          CSWPress
# 16       3                              Voice of the Martyrs
# 17       3                           The Church of Pentecost
# 18       2                                      CSW Advocacy
# 19       2                                     Open Doors UK
# 20       2                             Red Letter Christians
# 21       2                        Open Doors Southern Africa
# 22       2                                World Vision Kenya
# 23       2                                Open and Affirming
# 24       1                                     KAIROS Canada
# 25       1                               Inter Faith Network
# 26       1                  UCC Justice & Witness Ministries
# 27       1                                World Vision India
# 28       1                      European Academy of Religion
# 29       1                                    Joshua Project
# 30       1                              Anglican Centre Rome
# 31       1                           Ecumenical Review (WCC)
# 32       1                                     Barnabas Fund
# 33       1             Pilgrimage of Justice and Peace (WCC)
# 34       1                               FranciscanActionNet
# 35       1                        World Evangelical Alliance
# 36       1                   World Council of Churches (WCC)
# 37       1  Prayers from the World Council of Churches (WCC)
# 38       1                                              JPIT
# 39       1                                   World Vision UK
# 40       1                                Anglican Communion
# 41       1                                        CSW Europe
# 42       1                             Lutheran World Relief
# 43       1                                  World Vision AUS
# 44       1                                    Open Doors USA
# 45       1                                 ELCA World Hunger
# 46       1                               World Vision Canada
#
#                               Land
# 0                    United States
# 1                             None
# 2                    United States
# 3                             None
# 4                    United States
# 5                               日本
# 6                   United Kingdom
# 7                    United States
# 8                    United States
# 9                    United States
# 10                            None
# 11                  United Kingdom
# 12                   United States
# 13                            None
# 14                  United Kingdom
# 15                  United Kingdom
# 16                   United States
# 17                           Ghana
# 18                            None
# 19                  United Kingdom
# 20                            None
# 21                    South Africa
# 22                           Kenya
# 23                   United States
# 24                          Canada
# 25                  United Kingdom
# 26                   United States
# 27                           India
# 28                          Italia
# 29                            None
# 30                          Italia
# 31  Schweiz/Suisse/Svizzera/Svizra
# 32                            None
# 33                            None
# 34                   United States
# 35                   United States
# 36                            None
# 37                            None
# 38                  United Kingdom
# 39                  United Kingdom
# 40                            None
# 41                          France
# 42                   United States
# 43                       Australia
# 44                          Canada
# 45                   United States
# 46                          Canada

# %% [markdown]
# ##### Peak 4 - Identify tweet text

# %%
(ndf[ndf['text'].str.contains('The new year is almost here! Help us ring in 2020 by giving kids a future full of choices with a life-changing gift:')])
# Out:
#        author_id                                               text  \
# 234611  11859822  @3RingCommNYC The new year is almost here! Hel...
# 234612  11859822  @alvinfirstdevco The new year is almost here! ...
# 234613  11859822  @1bchambers The new year is almost here! Help ...
# 234614  11859822  @fuego_grace The new year is almost here! Help...
# 234615  11859822  @_Ellie_D_ The new year is almost here! Help u...
# ...          ...                                                ...
# 256821  11859822  @sharesurf3 The new year is almost here! Help ...
# 256822  11859822  @_trillestgunter The new year is almost here! ...
# 256823  11859822  @adscurlock The new year is almost here! Help ...
# 256824  11859822  @KerryStubbsSC The new year is almost here! He...
# 256825  11859822  @hawkeyeinaz_sue The new year is almost here! ...
#
#                       created_at  \
# 234611 2019-12-30 20:07:48+00:00
# 234612 2019-12-30 20:07:46+00:00
# 234613 2019-12-30 20:07:44+00:00
# 234614 2019-12-30 20:07:42+00:00
# 234615 2019-12-30 20:07:40+00:00
# ...                          ...
# 256821 2019-12-30 17:00:08+00:00
# 256822 2019-12-30 17:00:06+00:00
# 256823 2019-12-30 17:00:04+00:00
# 256824 2019-12-30 17:00:02+00:00
# 256825 2019-12-30 17:00:00+00:00
#
#                                         entities.mentions  \
# 234611  [{'start': 0, 'end': 13, 'username': '3RingCom...
# 234612  [{'start': 0, 'end': 16, 'username': 'alvinfir...
# 234613  [{'start': 0, 'end': 11, 'username': '1bchambe...
# 234614  [{'start': 0, 'end': 12, 'username': 'fuego_gr...
# 234615  [{'start': 0, 'end': 10, 'username': '_Ellie_D...
# ...                                                   ...
# 256821  [{'start': 0, 'end': 11, 'username': 'sharesur...
# 256822                                                NaN
# 256823  [{'start': 0, 'end': 11, 'username': 'adscurlo...
# 256824  [{'start': 0, 'end': 14, 'username': 'KerryStu...
# 256825  [{'start': 0, 'end': 16, 'username': 'hawkeyei...
#
#        entities.annotations entities.hashtags  \
# 234611                  NaN               NaN
# 234612                  NaN               NaN
# 234613                  NaN               NaN
# 234614                  NaN               NaN
# 234615                  NaN               NaN
# ...                     ...               ...
# 256821                  NaN               NaN
# 256822                  NaN               NaN
# 256823                  NaN               NaN
# 256824                  NaN               NaN
# 256825                  NaN               NaN
#
#                                            text_processed  is_reply  \
# 234611  [new, year, almost, help, ring, giving, kids, ...      True
# 234612  [new, year, almost, help, ring, giving, kids, ...      True
# 234613  [new, year, almost, help, ring, giving, kids, ...      True
# 234614  [new, year, almost, help, ring, giving, kids, ...      True
# 234615  [new, year, almost, help, ring, giving, kids, ...      True
# ...                                                   ...       ...
# 256821  [new, year, almost, help, ring, giving, kids, ...      True
# 256822  [new, year, almost, help, ring, giving, kids, ...      True
# 256823  [new, year, almost, help, ring, giving, kids, ...      True
# 256824  [new, year, almost, help, ring, giving, kids, ...      True
# 256825  [new, year, almost, help, ring, giving, kids, ...      True
#
#        referenced_type  length  tweet_count created_truncated  \
# 234611             NaN     154            1        2019-12-30
# 234612             NaN     157            1        2019-12-30
# 234613             NaN     152            1        2019-12-30
# 234614             NaN     153            1        2019-12-30
# 234615             NaN     151            1        2019-12-30
# ...                ...     ...          ...               ...
# 256821             NaN     152            1        2019-12-30
# 256822             NaN     157            1        2019-12-30
# 256823             NaN     152            1        2019-12-30
# 256824             NaN     155            1        2019-12-30
# 256825             NaN     157            1        2019-12-30
#
#                     name  public_metrics.followers_count        country
# 234611  World Vision USA                          554386  United States
# 234612  World Vision USA                          554386  United States
# 234613  World Vision USA                          554386  United States
# 234614  World Vision USA                          554386  United States
# 234615  World Vision USA                          554386  United States
# ...                  ...                             ...            ...
# 256821  World Vision USA                          554386  United States
# 256822  World Vision USA                          554386  United States
# 256823  World Vision USA                          554386  United States
# 256824  World Vision USA                          554386  United States
# 256825  World Vision USA                          554386  United States
#
# [22212 rows x 15 columns]

# %%
tweets_answer = (ndf[ndf['text']
                       .str
                       .contains('Thank you for your generosity. We’ll remind you on Giving Tuesday to empower kids in poverty with a MATCH opportunity!')
                      ]
                  )

rest_df = ndf.drop(tweets_answer.index, axis=0)


get_frequent_terms(rest_df['text'])
# Out:
#                          count
# token
# <-url->                  5771
# poverty                  3237
# giving                   3233
# check                    3230
# opportunity              3224
# ...                       ...
# faith advocacy           1
# faith advocacy resource  1
# faith attack             1
# faith attack freedom     1
# ️the crisis averted      1
#
# [58891 rows x 1 columns]

# %%
rest_df[(rest_df['text'].str.contains('poverty')) & (rest_df['text'].str.contains(re.compile(r'(C|c)heck')))]
# Out:
# C:\Users\Jo\AppData\Local\Temp/ipykernel_17000/1413107128.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   rest_df[(rest_df['text'].str.contains('poverty')) & (rest_df['text'].str.contains(re.compile(r'(C|c)heck')))]
#        author_id  \
# 290080  11859822
# 290082  11859822
# 290083  11859822
# 290084  11859822
# 290085  11859822
# ...          ...
# 293308  11859822
# 293309  11859822
# 293310  11859822
# 293311  11859822
# 294509  11859822
#
#                                                                                                                                                                                                                            text  \
# 290080  @inquewitch We’ll remind you on Giving Tuesday to empower kids in poverty with a MATCH opportunity! Check out what's in store... https://t.co/v6LOiTBRwe
# 290082  @QuintilianoJo We’ll remind you on Giving Tuesday to empower kids in poverty with a MATCH opportunity! Check out what's in store... https://t.co/uP66PER5pL
# 290083  @hawseyc94 We’ll remind you on Giving Tuesday to empower kids in poverty with a MATCH opportunity! Check out what's in store... https://t.co/ArfggW31pH
# 290084  @laineeluna We’ll remind you on Giving Tuesday to empower kids in poverty with a MATCH opportunity! Check out what's in store... https://t.co/hVcpCILOSp
# 290085  @AnnetteMardis48 We’ll remind you on Giving Tuesday to empower kids in poverty with a MATCH opportunity! Check out what's in store... https://t.co/GzXVKJUuwD
# ...                                                                                                                                                               ...
# 293308  @jadewood70 We’ll remind you on Giving Tuesday to empower kids in poverty with a MATCH opportunity! Check out what's in store... https://t.co/RrTwG3B5Oa
# 293309  @Elsie80146153 We’ll remind you on Giving Tuesday to empower kids in poverty with a MATCH opportunity! Check out what's in store... https://t.co/lSTreIBMTP
# 293310  @Kenneth23254449 We’ll remind you on Giving Tuesday to empower kids in poverty with a MATCH opportunity! Check out what's in store... https://t.co/lgU1LPOgov
# 293311  @GraceMc01767027 We’ll remind you on Giving Tuesday to empower kids in poverty with a MATCH opportunity! Check out what's in store... https://t.co/tOCC5v1tIe
# 294509  @Sandra31240413 We also work in some of the US's most distressed and underserved communities, where poverty is high and opportunities are limited. Here are more details for you to check out: https://t.co/KkfeF1NX1E.
#
#                       created_at  \
# 290080 2019-11-30 22:18:33+00:00
# 290082 2019-11-30 19:55:31+00:00
# 290083 2019-11-30 19:10:47+00:00
# 290084 2019-11-30 18:47:52+00:00
# 290085 2019-11-30 18:01:30+00:00
# ...                          ...
# 293308 2019-11-26 21:07:29+00:00
# 293309 2019-11-26 21:07:15+00:00
# 293310 2019-11-26 21:06:50+00:00
# 293311 2019-11-26 21:05:58+00:00
# 294509 2019-11-26 01:18:33+00:00
#
#                                                                            entities.mentions  \
# 290080  [{'start': 0, 'end': 11, 'username': 'inquewitch', 'id': '408865731'}]
# 290082  [{'start': 0, 'end': 14, 'username': 'QuintilianoJo', 'id': '717722015726055424'}]
# 290083  [{'start': 0, 'end': 10, 'username': 'hawseyc94', 'id': '1128462720095879170'}]
# 290084  NaN
# 290085  [{'start': 0, 'end': 16, 'username': 'AnnetteMardis48', 'id': '535856660'}]
# ...                                                                             ...
# 293308  [{'start': 0, 'end': 11, 'username': 'jadewood70', 'id': '250270399'}]
# 293309  NaN
# 293310  [{'start': 0, 'end': 16, 'username': 'Kenneth23254449', 'id': '855119193586454530'}]
# 293311  [{'start': 0, 'end': 16, 'username': 'GraceMc01767027', 'id': '829082741287251968'}]
# 294509  [{'start': 0, 'end': 15, 'username': 'Sandra31240413', 'id': '1067199648241197056'}]
#
#                                                                                entities.annotations  \
# 290080  NaN
# 290082  NaN
# 290083  NaN
# 290084  NaN
# 290085  NaN
# ...     ...
# 293308  NaN
# 293309  NaN
# 293310  NaN
# 293311  NaN
# 294509  [{'start': 44, 'end': 45, 'probability': 0.9211, 'type': 'Place', 'normalized_text': 'US'}]
#
#        entities.hashtags  \
# 290080  NaN
# 290082  NaN
# 290083  NaN
# 290084  NaN
# 290085  NaN
# ...     ...
# 293308  NaN
# 293309  NaN
# 293310  NaN
# 293311  NaN
# 294509  NaN
#
#                                                                                                                   text_processed  \
# 290080  [remind, giving, tuesday, empower, kids, poverty, match, opportunity, check, what's, store, <-url->]
# 290082  [remind, giving, tuesday, empower, kids, poverty, match, opportunity, check, what's, store, <-url->]
# 290083  [remind, giving, tuesday, empower, kids, poverty, match, opportunity, check, what's, store, <-url->]
# 290084  [remind, giving, tuesday, empower, kids, poverty, match, opportunity, check, what's, store, <-url->]
# 290085  [remind, giving, tuesday, empower, kids, poverty, match, opportunity, check, what's, store, <-url->]
# ...                                                                                                      ...
# 293308  [remind, giving, tuesday, empower, kids, poverty, match, opportunity, check, what's, store, <-url->]
# 293309  [remind, giving, tuesday, empower, kids, poverty, match, opportunity, check, what's, store, <-url->]
# 293310  [remind, giving, tuesday, empower, kids, poverty, match, opportunity, check, what's, store, <-url->]
# 293311  [remind, giving, tuesday, empower, kids, poverty, match, opportunity, check, what's, store, <-url->]
# 294509  [also, work, us's, distressed, underserved, communities, poverty, high, opportunities, limited, details, check, <-url->]
#
#         is_reply referenced_type  length  tweet_count created_truncated  \
# 290080  True      NaN             152     1            2019-11-30
# 290082  True      NaN             155     1            2019-11-30
# 290083  True      NaN             151     1            2019-11-30
# 290084  True      NaN             152     1            2019-11-30
# 290085  True      NaN             157     1            2019-11-30
# ...      ...      ...             ...    ..                   ...
# 293308  True      NaN             152     1            2019-11-26
# 293309  True      NaN             155     1            2019-11-26
# 293310  True      NaN             157     1            2019-11-26
# 293311  True      NaN             157     1            2019-11-26
# 294509  True      replied_to      215     1            2019-11-26
#
#                     name  public_metrics.followers_count        country
# 290080  World Vision USA  554386                          United States
# 290082  World Vision USA  554386                          United States
# 290083  World Vision USA  554386                          United States
# 290084  World Vision USA  554386                          United States
# 290085  World Vision USA  554386                          United States
# ...                  ...     ...                                    ...
# 293308  World Vision USA  554386                          United States
# 293309  World Vision USA  554386                          United States
# 293310  World Vision USA  554386                          United States
# 293311  World Vision USA  554386                          United States
# 294509  World Vision USA  554386                          United States
#
# [3209 rows x 15 columns]

# %%
rest_df[(rest_df['text']
         .str
         .contains('We’ll remind you on Giving Tuesday to empower kids in poverty with a MATCH opportunity! Check out what\'s in store'))]
# Out:
#        author_id  \
# 290080  11859822
# 290082  11859822
# 290083  11859822
# 290084  11859822
# 290085  11859822
# ...          ...
# 293307  11859822
# 293308  11859822
# 293309  11859822
# 293310  11859822
# 293311  11859822
#
#                                                                                                                                                                  text  \
# 290080  @inquewitch We’ll remind you on Giving Tuesday to empower kids in poverty with a MATCH opportunity! Check out what's in store... https://t.co/v6LOiTBRwe
# 290082  @QuintilianoJo We’ll remind you on Giving Tuesday to empower kids in poverty with a MATCH opportunity! Check out what's in store... https://t.co/uP66PER5pL
# 290083  @hawseyc94 We’ll remind you on Giving Tuesday to empower kids in poverty with a MATCH opportunity! Check out what's in store... https://t.co/ArfggW31pH
# 290084  @laineeluna We’ll remind you on Giving Tuesday to empower kids in poverty with a MATCH opportunity! Check out what's in store... https://t.co/hVcpCILOSp
# 290085  @AnnetteMardis48 We’ll remind you on Giving Tuesday to empower kids in poverty with a MATCH opportunity! Check out what's in store... https://t.co/GzXVKJUuwD
# ...                                                                                                                                                               ...
# 293307  @lorraine_neve We’ll remind you on Giving Tuesday to empower kids in poverty with a MATCH opportunity! Check out what's in store... https://t.co/xqUHKMTPt3
# 293308  @jadewood70 We’ll remind you on Giving Tuesday to empower kids in poverty with a MATCH opportunity! Check out what's in store... https://t.co/RrTwG3B5Oa
# 293309  @Elsie80146153 We’ll remind you on Giving Tuesday to empower kids in poverty with a MATCH opportunity! Check out what's in store... https://t.co/lSTreIBMTP
# 293310  @Kenneth23254449 We’ll remind you on Giving Tuesday to empower kids in poverty with a MATCH opportunity! Check out what's in store... https://t.co/lgU1LPOgov
# 293311  @GraceMc01767027 We’ll remind you on Giving Tuesday to empower kids in poverty with a MATCH opportunity! Check out what's in store... https://t.co/tOCC5v1tIe
#
#                       created_at  \
# 290080 2019-11-30 22:18:33+00:00
# 290082 2019-11-30 19:55:31+00:00
# 290083 2019-11-30 19:10:47+00:00
# 290084 2019-11-30 18:47:52+00:00
# 290085 2019-11-30 18:01:30+00:00
# ...                          ...
# 293307 2019-11-26 21:07:33+00:00
# 293308 2019-11-26 21:07:29+00:00
# 293309 2019-11-26 21:07:15+00:00
# 293310 2019-11-26 21:06:50+00:00
# 293311 2019-11-26 21:05:58+00:00
#
#                                                                            entities.mentions  \
# 290080  [{'start': 0, 'end': 11, 'username': 'inquewitch', 'id': '408865731'}]
# 290082  [{'start': 0, 'end': 14, 'username': 'QuintilianoJo', 'id': '717722015726055424'}]
# 290083  [{'start': 0, 'end': 10, 'username': 'hawseyc94', 'id': '1128462720095879170'}]
# 290084  NaN
# 290085  [{'start': 0, 'end': 16, 'username': 'AnnetteMardis48', 'id': '535856660'}]
# ...                                                                             ...
# 293307  [{'start': 0, 'end': 14, 'username': 'lorraine_neve', 'id': '826849201862692864'}]
# 293308  [{'start': 0, 'end': 11, 'username': 'jadewood70', 'id': '250270399'}]
# 293309  NaN
# 293310  [{'start': 0, 'end': 16, 'username': 'Kenneth23254449', 'id': '855119193586454530'}]
# 293311  [{'start': 0, 'end': 16, 'username': 'GraceMc01767027', 'id': '829082741287251968'}]
#
#        entities.annotations entities.hashtags  \
# 290080  NaN                  NaN
# 290082  NaN                  NaN
# 290083  NaN                  NaN
# 290084  NaN                  NaN
# 290085  NaN                  NaN
# ...     ...                  ...
# 293307  NaN                  NaN
# 293308  NaN                  NaN
# 293309  NaN                  NaN
# 293310  NaN                  NaN
# 293311  NaN                  NaN
#
#                                                                                               text_processed  \
# 290080  [remind, giving, tuesday, empower, kids, poverty, match, opportunity, check, what's, store, <-url->]
# 290082  [remind, giving, tuesday, empower, kids, poverty, match, opportunity, check, what's, store, <-url->]
# 290083  [remind, giving, tuesday, empower, kids, poverty, match, opportunity, check, what's, store, <-url->]
# 290084  [remind, giving, tuesday, empower, kids, poverty, match, opportunity, check, what's, store, <-url->]
# 290085  [remind, giving, tuesday, empower, kids, poverty, match, opportunity, check, what's, store, <-url->]
# ...                                                                                                      ...
# 293307  [remind, giving, tuesday, empower, kids, poverty, match, opportunity, check, what's, store, <-url->]
# 293308  [remind, giving, tuesday, empower, kids, poverty, match, opportunity, check, what's, store, <-url->]
# 293309  [remind, giving, tuesday, empower, kids, poverty, match, opportunity, check, what's, store, <-url->]
# 293310  [remind, giving, tuesday, empower, kids, poverty, match, opportunity, check, what's, store, <-url->]
# 293311  [remind, giving, tuesday, empower, kids, poverty, match, opportunity, check, what's, store, <-url->]
#
#         is_reply referenced_type  length  tweet_count created_truncated  \
# 290080  True      NaN             152     1            2019-11-30
# 290082  True      NaN             155     1            2019-11-30
# 290083  True      NaN             151     1            2019-11-30
# 290084  True      NaN             152     1            2019-11-30
# 290085  True      NaN             157     1            2019-11-30
# ...      ...      ...             ...    ..                   ...
# 293307  True      NaN             155     1            2019-11-26
# 293308  True      NaN             152     1            2019-11-26
# 293309  True      NaN             155     1            2019-11-26
# 293310  True      NaN             157     1            2019-11-26
# 293311  True      NaN             157     1            2019-11-26
#
#                     name  public_metrics.followers_count        country
# 290080  World Vision USA  554386                          United States
# 290082  World Vision USA  554386                          United States
# 290083  World Vision USA  554386                          United States
# 290084  World Vision USA  554386                          United States
# 290085  World Vision USA  554386                          United States
# ...                  ...     ...                                    ...
# 293307  World Vision USA  554386                          United States
# 293308  World Vision USA  554386                          United States
# 293309  World Vision USA  554386                          United States
# 293310  World Vision USA  554386                          United States
# 293311  World Vision USA  554386                          United States
#
# [3207 rows x 15 columns]

# %%
tweets_call = (rest_df[(rest_df['text']
                         .str
                         .contains('We’ll remind you on Giving Tuesday to empower kids in poverty with a MATCH opportunity! Check out what\'s in store'))
                     ]
             )

rest2_df = rest_df.drop(tweets_call.index, axis=0)
get_frequent_terms(rest2_df['text'])
# Out:
#                              count
# token
# <-url->                      2564
# <-url-> <-url->              298
# world                        246
# violence                     230
# people                       209
# ...                          ...
# faith #redwednesday <-url->  1
# faith <-url-> <-url->        1
# faith action                 1
# faith action volunteering    1
# ️the crisis averted          1
#
# [58872 rows x 1 columns]

# %% [markdown]
# ##### Last Check

# %%
tweet_call = 'The new year is almost here! Help us ring in 2020 by giving kids a future full of choices with a life-changing gift:'
tweet_answer = 'Thank you for your generosity. We’ll remind you on Giving Tuesday to empower kids in poverty with a MATCH opportunity! Check out what\'s in store...'

def drop_check(df, tweet):
    return df[df['text'].str.contains(tweet)]

def drop_peak(df, tweet):
    drop_df = df[df['text'].str.contains(tweet)]
    return df.drop(drop_df.index, axis=0)

def drop_plot(df):
    fig, axes = plt.subplots(nrows=1, ncols=1, figsize = (15, 5))
    fig.tight_layout()
    (df
     .rolling(7)
     .mean()
     .rename(columns={"counts": "1W SMA"})
     .plot(ax=axes)
    )

    axes.set_xlabel('Date')
    axes.set_ylabel('Number of Tweets')
    axes.set_title('Simple Moving Average of Number of Tweets')
    
    
final_df = drop_peak(tdf, tweet_call)
drop_plot(tweet_counter(final_df))

# %% [markdown]
# ## Save result

# %%
def drop_peak(df, tweet):
    drop_df = df[df['text'].str.contains(tweet)]
    return df.drop(drop_df.index, axis=0)

final_df = drop_peak(df, tweet_call)
final_df
# Out:
#                  author_id                                               text  \
# 0       697374646614781952  RT @AWalkerSmith7: @AaccCeta @ArchbishopSapit ...
# 1       697374646614781952  RT @sceptwic: Another important step in road t...
# 2       697374646614781952  Congratulations Ven Rose Okeno ACK Diocese of ...
# 3       697374646614781952  Consecration Service of Ven Rose Okeno ACK Dio...
# 4       697374646614781952  We are looking forward to today’s Consecration...
# ...                    ...                                                ...
# 308837          2193947323  In our New Year Message to the Nation we proff...
# 308838          2193947323  RT @NewsDayZimbabwe: THE @zccinzim has launche...
# 308839          2193947323  We can choose the route of engagement or that ...
# 308840          2193947323  For many Zimbabweans, 2019 has come amidst muc...
# 308841          2193947323  “From a position of reason, our problems seem ...
#
#        lang                                  referenced_tweets reply_settings  \
# 0        en  [{'type': 'retweeted', 'id': '1437029861676228...       everyone
# 1        en  [{'type': 'retweeted', 'id': '1437043141979295...       everyone
# 2        en                                                NaN       everyone
# 3        en                                                NaN       everyone
# 4        en  [{'type': 'replied_to', 'id': '143695708915549...       everyone
# ...     ...                                                ...            ...
# 308837   en  [{'type': 'quoted', 'id': '1082850893807144962'}]       everyone
# 308838   en  [{'type': 'retweeted', 'id': '1082932233500065...       everyone
# 308839   en                                                NaN       everyone
# 308840   en                                                NaN       everyone
# 308841   en                                                NaN       everyone
#
#             conversation_id                   id                created_at  \
# 0       1437051433480753156  1437051433480753156 2021-09-12 13:52:15+00:00
# 1       1437051325255192582  1437051325255192582 2021-09-12 13:51:49+00:00
# 2       1436979065114800131  1436979065114800131 2021-09-12 09:04:41+00:00
# 3       1436975615480041473  1436975615480041473 2021-09-12 08:50:59+00:00
# 4       1436957089155493889  1436957092787757056 2021-09-12 07:37:22+00:00
# ...                     ...                  ...                       ...
# 308837  1082937561537044480  1082937561537044480 2019-01-09 09:50:09+00:00
# 308838  1082934512777117696  1082934512777117696 2019-01-09 09:38:02+00:00
# 308839  1082904479526240256  1082904479526240256 2019-01-09 07:38:41+00:00
# 308840  1082548265617371137  1082548265617371137 2019-01-08 08:03:13+00:00
# 308841  1082339383217393666  1082339383217393666 2019-01-07 18:13:12+00:00
#
#                                         entities.mentions  \
# 0       [{'start': 3, 'end': 17, 'username': 'AWalkerS...
# 1       [{'start': 3, 'end': 12, 'username': 'sceptwic...
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 308837                                                NaN
# 308838  [{'start': 3, 'end': 19, 'username': 'NewsDayZ...
# 308839  [{'start': 211, 'end': 227, 'username': 'NewsD...
# 308840  [{'start': 187, 'end': 199, 'username': 'EFZZI...
# 308841  [{'start': 148, 'end': 161, 'username': 'kenne...
#
#                                      entities.annotations  ...  \
# 0       [{'start': 93, 'end': 95, 'probability': 0.919...  ...
# 1                                                     NaN  ...
# 2       [{'start': 16, 'end': 29, 'probability': 0.516...  ...
# 3       [{'start': 124, 'end': 147, 'probability': 0.5...  ...
# 4       [{'start': 116, 'end': 124, 'probability': 0.6...  ...
# ...                                                   ...  ...
# 308837                                                NaN  ...
# 308838                                                NaN  ...
# 308839                                                NaN  ...
# 308840                                                NaN  ...
# 308841  [{'start': 137, 'end': 142, 'probability': 0.7...  ...
#
#                                             entities.urls  \
# 0                                                     NaN
# 1                                                     NaN
# 2       [{'start': 213, 'end': 236, 'url': 'https://t....
# 3       [{'start': 239, 'end': 262, 'url': 'https://t....
# 4                                                     NaN
# ...                                                   ...
# 308837  [{'start': 271, 'end': 294, 'url': 'https://t....
# 308838                                                NaN
# 308839  [{'start': 183, 'end': 206, 'url': 'https://t....
# 308840  [{'start': 264, 'end': 287, 'url': 'https://t....
# 308841  [{'start': 211, 'end': 234, 'url': 'https://t....
#
#         in_reply_to_user_id  geo.place_id  geo.coordinates.type  \
# 0                       NaN           NaN                   NaN
# 1                       NaN           NaN                   NaN
# 2                       NaN           NaN                   NaN
# 3                       NaN           NaN                   NaN
# 4        697374646614781952           NaN                   NaN
# ...                     ...           ...                   ...
# 308837                  NaN           NaN                   NaN
# 308838                  NaN           NaN                   NaN
# 308839                  NaN           NaN                   NaN
# 308840                  NaN           NaN                   NaN
# 308841                  NaN           NaN                   NaN
#
#        geo.coordinates.coordinates withheld.copyright withheld.country_codes  \
# 0                              NaN                NaN                    NaN
# 1                              NaN                NaN                    NaN
# 2                              NaN                NaN                    NaN
# 3                              NaN                NaN                    NaN
# 4                              NaN                NaN                    NaN
# ...                            ...                ...                    ...
# 308837                         NaN                NaN                    NaN
# 308838                         NaN                NaN                    NaN
# 308839                         NaN                NaN                    NaN
# 308840                         NaN                NaN                    NaN
# 308841                         NaN                NaN                    NaN
#
#        withheld.scope entities.cashtags  \
# 0                 NaN               NaN
# 1                 NaN               NaN
# 2                 NaN               NaN
# 3                 NaN               NaN
# 4                 NaN               NaN
# ...               ...               ...
# 308837            NaN               NaN
# 308838            NaN               NaN
# 308839            NaN               NaN
# 308840            NaN               NaN
# 308841            NaN               NaN
#
#                                            text_processed
# 0       [thanking, god, historic, moment, church, hist...
# 1       [another, important, step, road, #justicedigni...
# 2       [congratulations, ven, rose, okeno, ack, dioce...
# 3       [consecration, service, ven, rose, okeno, ack,...
# 4       [looking, forward, today, consecration, enthro...
# ...                                                   ...
# 308837  [new, year, message, nation, proffered, areas,...
# 308838  [launched, fresh, bid, broker, dialogue, presi...
# 308839  [choose, route, engagement, conflict, route, i...
# 308840  [many, zimbabweans, come, amidst, much, hardsh...
# 308841  [position, reason, problems, seem, political, ...
#
# [243009 rows x 25 columns]

# %%
final_df.to_pickle('Your/Data/Path/tweet_dataframe_p4.pkl')
