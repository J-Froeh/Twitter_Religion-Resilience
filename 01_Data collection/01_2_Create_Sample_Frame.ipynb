# %%
import glob
import json
import nltk
from nltk.tokenize import TweetTokenizer
import pandas as pd
import re
from string import punctuation

# %% [markdown]
# ## Loading Data

# %%
# Load tweets as JSON
allTweets_json = {'tweets': []}
for file in glob.glob('Your/Data/Path/*'):
    with open(file) as data_file:
        json_data = json.load(data_file)
        for tweet in json_data['tweet_data']:
            allTweets_json['tweets'].append(tweet)
allTweets_json
# Out:
# {'tweets': [{'in_reply_to_user_id': '1021209821695991810',
#    'entities': {'urls': [{'start': 30,
#       'end': 53,
#       'url': 'https://t.co/Z4HWMRlwMU',
#       'expanded_url': 'https://twitter.com/haejin28_/status/1079957943343144960/photo/1',
#       'display_url': 'pic.twitter.com/Z4HWMRlwMU'}]},
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 1,
#     'quote_count': 0},
#    'lang': 'en',
#    'id': '1079957943343144960',
#    'reply_settings': 'everyone',
#    'referenced_tweets': [{'type': 'replied_to', 'id': '1079957322275799040'}],
#    'conversation_id': '1079710990441181185',
#    'text': '@Panchin083 Hahahah i wuv you https://t.co/Z4HWMRlwMU',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '989088763094732805'},
#   {'in_reply_to_user_id': '772925896130961408',
#    'public_metrics': {'retweet_count': 1,
#     'reply_count': 1,
#     'like_count': 1,
#     'quote_count': 0},
#    'lang': 'en',
#    'id': '1079957943334912000',
#    'reply_settings': 'everyone',
#    'referenced_tweets': [{'type': 'replied_to', 'id': '1079953008635592704'}],
#    'conversation_id': '1079953008635592704',
#    'text': '@ViciousRalph Why you doubt yourself? Figure out why and what you need to work on and do better. Keep your head up and keep moving, step over ya obstacles, G.',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '954046885467246592'},
#   {'public_metrics': {'retweet_count': 29,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'entities': {'mentions': [{'start': 3,
#       'end': 7,
#       'username': 'tcm',
#       'id': '25071402'},
#      {'start': 100, 'end': 110, 'username': 'BenMank77', 'id': '164354823'}]},
#    'id': '1079957943334899712',
#    'reply_settings': 'everyone',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1079957890784481282'}],
#    'conversation_id': '1079957943334899712',
#    'text': "RT @tcm: Still struggling to find the perfect cocktail to ring in the New Year? Keep it simple with @BenMank77's drink of choice: @jamesonw…",
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '28752714'},
#   {'entities': {'urls': [{'start': 22,
#       'end': 45,
#       'url': 'https://t.co/oBcfD6HPgj',
#       'expanded_url': 'https://twitter.com/emilyxsnapp/status/1079280554560765958/photo/1',
#       'display_url': 'pic.twitter.com/oBcfD6HPgj'}]},
#    'public_metrics': {'retweet_count': 13656,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'id': '1079957943330705409',
#    'reply_settings': 'everyone',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1079280554560765958'}],
#    'conversation_id': '1079957943330705409',
#    'text': 'RT @emilyxsnapp: fuck https://t.co/oBcfD6HPgj',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '231199325'},
#   {'public_metrics': {'retweet_count': 3,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'entities': {'annotations': [{'start': 71,
#       'end': 73,
#       'probability': 0.9174,
#       'type': 'Other',
#       'normalized_text': 'God'}],
#     'mentions': [{'start': 3,
#       'end': 18,
#       'username': 'entwinedglobal',
#       'id': '4361211137'}]},
#    'id': '1079957943330627584',
#    'reply_settings': 'everyone',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1079957919792353280'}],
#    'conversation_id': '1079957943330627584',
#    'text': "RT @entwinedglobal: We wish you all a prosperous New Year 2019 full of God's blessings. Mobile: 0732998899\nEmail: info@entwined.co.ke\n#Weca…",
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '809111804035104768'},
#   {'entities': {'urls': [{'start': 31,
#       'end': 54,
#       'url': 'https://t.co/mFwQxXe980',
#       'expanded_url': 'https://twitter.com/halfhalfbastard/status/1079955614929960960',
#       'display_url': 'twitter.com/halfhalfbastar…'}],
#     'annotations': [{'start': 10,
#       'end': 15,
#       'probability': 0.5916,
#       'type': 'Organization',
#       'normalized_text': 'Subway'}]},
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 1},
#    'lang': 'en',
#    'id': '1079957943326396416',
#    'reply_settings': 'everyone',
#    'referenced_tweets': [{'type': 'quoted', 'id': '1079955614929960960'}],
#    'conversation_id': '1079957943326396416',
#    'text': 'Actually, Subway worked for me https://t.co/mFwQxXe980',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '136551906'},
#   {'entities': {'urls': [{'start': 71,
#       'end': 94,
#       'url': 'https://t.co/RNLO3P7oaB',
#       'expanded_url': 'https://twitter.com/coast2coastal_/status/1077990461481144321',
#       'display_url': 'twitter.com/coast2coastal_…'}]},
#    'public_metrics': {'retweet_count': 46748,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'id': '1079957943326392326',
#    'reply_settings': 'everyone',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1078443586587258880'}],
#    'conversation_id': '1079957943326392326',
#    'text': 'RT @optimistic__Ro: I retweet this stuff so I can go watch them later😂 https://t.co/RNLO3P7oaB',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '752477365268131841'},
#   {'entities': {'urls': [{'start': 115,
#       'end': 138,
#       'url': 'https://t.co/YObj7lZo6D',
#       'expanded_url': 'https://t.co/YObj7lZo6D',
#       'display_url': 't.co/YObj7lZo6D'}],
#     'annotations': [{'start': 48,
#       'end': 51,
#       'probability': 0.7247,
#       'type': 'Person',
#       'normalized_text': 'Stan'}]},
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 1,
#     'quote_count': 0},
#    'lang': 'en',
#    'id': '1079957943318122498',
#    'reply_settings': 'everyone',
#    'conversation_id': '1079957943318122498',
#    'text': 'I’m actually 15. Not sure of my sexuality, main Stan is also bts but still got them right! And rest got right  too https://t.co/YObj7lZo6D',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '4872698895'},
#   {'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'entities': {'annotations': [{'start': 45,
#       'end': 56,
#       'probability': 0.9956,
#       'type': 'Person',
#       'normalized_text': 'Kris Richard'}]},
#    'id': '1079957943313989633',
#    'reply_settings': 'everyone',
#    'conversation_id': '1079957943313989633',
#    'text': 'I’m so bummed that we’re probably gonna lose Kris Richard after this season 😣',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '240119441'},
#   {'in_reply_to_user_id': '2488576712',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'entities': {'mentions': [{'start': 0,
#       'end': 11,
#       'username': 'ColbyBrock',
#       'id': '2488576712'}]},
#    'id': '1079957943309791233',
#    'reply_settings': 'everyone',
#    'referenced_tweets': [{'type': 'replied_to', 'id': '1079889037740060672'}],
#    'conversation_id': '1079889037740060672',
#    'text': '@ColbyBrock my ex toxic relationship. never will i fall that low again, ever.',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '2890137690'},
#   {'in_reply_to_user_id': '3311966454',
#    'entities': {'urls': [{'start': 23,
#       'end': 46,
#       'url': 'https://t.co/cQK6mDYjJ1',
#       'expanded_url': 'https://twitter.com/DukeNBA/status/1079794725803253761',
#       'display_url': 'twitter.com/DukeNBA/status…'}],
#     'mentions': [{'start': 0,
#       'end': 11,
#       'username': 'macklesmif',
#       'id': '3311966454'}]},
#    'public_metrics': {'retweet_count': 1,
#     'reply_count': 1,
#     'like_count': 2,
#     'quote_count': 0},
#    'lang': 'en',
#    'id': '1079957943309656064',
#    'reply_settings': 'everyone',
#    'referenced_tweets': [{'type': 'quoted', 'id': '1079794725803253761'}],
#    'conversation_id': '1079957943309656064',
#    'text': '@macklesmif duke sucks https://t.co/cQK6mDYjJ1',
#    'geo': {'place_id': '6083b03ae37cd913'},
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '215915168'},
#   {'public_metrics': {'retweet_count': 893,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'entities': {'mentions': [{'start': 3,
#       'end': 14,
#       'username': 'FauxPelini',
#       'id': '226813554'}]},
#    'id': '1079957943301406720',
#    'reply_settings': 'everyone',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1079957067681710080'}],
#    'conversation_id': '1079957943301406720',
#    'text': 'RT @FauxPelini: Don’t forget to set your clocks ahead one hour tonight everybody',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '378407478'},
#   {'in_reply_to_user_id': '227837742',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'entities': {'annotations': [{'start': 73,
#       'end': 80,
#       'probability': 0.9265,
#       'type': 'Person',
#       'normalized_text': 'Anderson'},
#      {'start': 84,
#       'end': 87,
#       'probability': 0.8687,
#       'type': 'Person',
#       'normalized_text': 'Andy'}],
#     'mentions': [{'start': 0,
#       'end': 6,
#       'username': 'AC360',
#       'id': '227837742'},
#      {'start': 7, 'end': 15, 'username': 'DUALIPA', 'id': '154101116'},
#      {'start': 16, 'end': 30, 'username': 'kenanthompson', 'id': '946618914'},
#      {'start': 31, 'end': 41, 'username': 'GayleKing', 'id': '29546945'},
#      {'start': 42, 'end': 55, 'username': 'LennyKravitz', 'id': '23006794'},
#      {'start': 56, 'end': 60, 'username': 'JLo', 'id': '85603854'},
#      {'start': 61, 'end': 72, 'username': 'LeahRemini', 'id': '37000209'}]},
#    'id': '1079957943297212416',
#    'reply_settings': 'everyone',
#    'referenced_tweets': [{'type': 'replied_to', 'id': '1079927513990684672'}],
#    'conversation_id': '1079927513990684672',
#    'text': '@AC360 @DUALIPA @kenanthompson @GayleKing @LennyKravitz @JLo @LeahRemini Anderson &amp; Andy ... pure entertainment!!!!💙',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '1343348761'},
#   {'entities': {'urls': [{'start': 53,
#       'end': 76,
#       'url': 'https://t.co/uAm3WIvVdo',
#       'expanded_url': 'https://twitter.com/ItsPWong/status/1079957943292817408/photo/1',
#       'display_url': 'pic.twitter.com/uAm3WIvVdo'},
#      {'start': 53,
#       'end': 76,
#       'url': 'https://t.co/uAm3WIvVdo',
#       'expanded_url': 'https://twitter.com/ItsPWong/status/1079957943292817408/photo/1',
#       'display_url': 'pic.twitter.com/uAm3WIvVdo'}]},
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'id': '1079957943292817408',
#    'reply_settings': 'everyone',
#    'conversation_id': '1079957943292817408',
#    'text': 'Soooo many people y’all! Thanks for being there ☺️☺️ https://t.co/uAm3WIvVdo',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '45282274'},
#   {'entities': {'urls': [{'start': 77,
#       'end': 100,
#       'url': 'https://t.co/pnCk29Ep1C',
#       'expanded_url': 'http://ow.ly/eRVn30mYkmp',
#       'display_url': 'ow.ly/eRVn30mYkmp'}]},
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'id': '1079957943288766464',
#    'reply_settings': 'everyone',
#    'conversation_id': '1079957943288766464',
#    'text': 'Explore the functionality, customer service &amp; value&gt; Alumacraft Boats https://t.co/pnCk29Ep1C RT @Frankfort_Vine_',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '131643746'},
#   {'entities': {'urls': [{'start': 116,
#       'end': 139,
#       'url': 'https://t.co/5Cix9swq1s',
#       'expanded_url': 'https://on.msnbc.com/2EWv1kG',
#       'display_url': 'on.msnbc.com/2EWv1kG'}],
#     'annotations': [{'start': 11,
#       'end': 22,
#       'probability': 0.9936,
#       'type': 'Person',
#       'normalized_text': 'Barack Obama'},
#      {'start': 63,
#       'end': 69,
#       'probability': 0.9992,
#       'type': 'Place',
#       'normalized_text': 'America'}],
#     'mentions': [{'start': 3,
#       'end': 9,
#       'username': 'MSNBC',
#       'id': '2836421'}]},
#    'public_metrics': {'retweet_count': 3400,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'id': '1079957943288705024',
#    'reply_settings': 'everyone',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1079852472057905154'}],
#    'conversation_id': '1079957943288705024',
#    'text': 'RT @MSNBC: Barack Obama has been voted the Most Admired Man in America for the 11th time, per annual Gallup poll.   https://t.co/5Cix9swq1s',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '22047365'},
#   {'entities': {'urls': [{'start': 189,
#       'end': 212,
#       'url': 'https://t.co/hGQpjJyH32',
#       'expanded_url': 'https://www.instagram.com/p/BsFBcQAABSs/?utm_source=ig_twitter_share&igshid=1l36y3y5ezn86',
#       'display_url': 'instagram.com/p/BsFBcQAABSs/…'}],
#     'annotations': [{'start': 17,
#       'end': 29,
#       'probability': 0.988,
#       'type': 'Person',
#       'normalized_text': 'Drew McIntyre'},
#      {'start': 40,
#       'end': 52,
#       'probability': 0.9912,
#       'type': 'Person',
#       'normalized_text': 'Dolph Ziggler'},
#      {'start': 87,
#       'end': 98,
#       'probability': 0.9969,
#       'type': 'Person',
#       'normalized_text': 'Seth Rollins'}]},
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'id': '1079957943276265472',
#    'reply_settings': 'everyone',
#    'conversation_id': '1079957943276265472',
#    'text': 'Results on raw-\n•Drew McIntyre defeated Dolph Ziggler in a steel cage.\n•a segment with Seth Rollins saying he wants his IC championship rematch until triple h would go into a speech about… https://t.co/hGQpjJyH32',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '1025244538535723009'},
#   {'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'id': '1079957943276240897',
#    'reply_settings': 'everyone',
#    'conversation_id': '1079957943276240897',
#    'text': 'The best way to gain self-confidence is to do what you are afraid to do.  ~Author Unknown',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '167555307'},
#   {'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 3,
#     'quote_count': 0},
#    'lang': 'en',
#    'id': '1079957943276032002',
#    'reply_settings': 'everyone',
#    'conversation_id': '1079957943276032002',
#    'text': 'I so love the weather today ❄',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '3074826612'},
#   {'entities': {'urls': [{'start': 70,
#       'end': 93,
#       'url': 'https://t.co/rIAMEcBudf',
#       'expanded_url': 'https://www.instagram.com/p/BsFAfqXB7_Z/?utm_source=ig_twitter_share&igshid=186pr1ar5ebkx',
#       'display_url': 'instagram.com/p/BsFAfqXB7_Z/…',
#       'status': 200,
#       'title': 'Login • Instagram',
#       'description': 'Welcome back to Instagram. Sign in to check out what your friends, family & interests have been capturing & sharing around the world.',
#       'unwound_url': 'https://www.instagram.com/accounts/login/'}]},
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 2,
#     'quote_count': 0},
#    'lang': 'en',
#    'id': '1079957943272067074',
#    'reply_settings': 'everyone',
#    'conversation_id': '1079957943272067074',
#    'text': 'Happy new year... Let’s all strive to post less, and do more in 2019! https://t.co/rIAMEcBudf',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '94695326'},
#   {'public_metrics': {'retweet_count': 60,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'entities': {'annotations': [{'start': 27,
#       'end': 32,
#       'probability': 0.9697,
#       'type': 'Person',
#       'normalized_text': 'Jongin'}],
#     'mentions': [{'start': 3,
#       'end': 10,
#       'username': 'NaenRy',
#       'id': '967760172943724544'},
#      {'start': 12,
#       'end': 26,
#       'username': 'KlMJUNCOTTONS',
#       'id': '1131708219078746112'}]},
#    'id': '1079957943272067073',
#    'reply_settings': 'everyone',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1079920259992186880'}],
#    'conversation_id': '1079957943272067073',
#    'text': "RT @NaenRy: @KlMJUNCOTTONS Jongin: HyuuuuUUUNng please I can't use my phone please check on her 🙏🙏🙏🙏🙏😭😭😭😭\nManager-nim: jfc okay OKAY just s…",
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '1005587462498840576'},
#   {'in_reply_to_user_id': '204163636',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'entities': {'mentions': [{'start': 0,
#       'end': 7,
#       'username': 'OH_mes',
#       'id': '204163636'}]},
#    'id': '1079957943271882752',
#    'reply_settings': 'everyone',
#    'referenced_tweets': [{'type': 'replied_to', 'id': '1079954572389474304'}],
#    'conversation_id': '1079954572389474304',
#    'text': '@OH_mes whaaaaaaaat . eunjiwon wouldnt approve',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '816399912300474368'},
#   {'in_reply_to_user_id': '2478509173',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 1,
#     'like_count': 6,
#     'quote_count': 0},
#    'lang': 'en',
#    'entities': {'mentions': [{'start': 0,
#       'end': 12,
#       'username': 'dirkmacgirk',
#       'id': '2478509173'}]},
#    'id': '1079957943267651584',
#    'reply_settings': 'everyone',
#    'conversation_id': '1079957943267651584',
#    'text': '@dirkmacgirk Reporting in: The cherry moonshine liquor tastes exactly like cough syrup. Do not recommend. 0/10, no stars, unsubscribed.',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '2474152261'},
#   {'entities': {'urls': [{'start': 180,
#       'end': 203,
#       'url': 'https://t.co/mDxNbNuguL',
#       'expanded_url': 'https://www.instagram.com/p/BsFAOEdBH9B/?utm_source=ig_twitter_share&igshid=brzggklhffq6',
#       'display_url': 'instagram.com/p/BsFAOEdBH9B/…'}],
#     'hashtags': [{'start': 85, 'end': 95, 'tag': 'yycliving'},
#      {'start': 96, 'end': 113, 'tag': 'yycsmallbusiness'},
#      {'start': 114, 'end': 121, 'tag': 'yycnow'},
#      {'start': 122, 'end': 131, 'tag': 'yyclocal'},
#      {'start': 132, 'end': 147, 'tag': 'yycnewyearseve'},
#      {'start': 148, 'end': 156, 'tag': 'newyear'},
#      {'start': 157, 'end': 169, 'tag': 'newyearseve'},
#      {'start': 170, 'end': 178, 'tag': 'calgary'}]},
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'id': '1079957943263678465',
#    'reply_settings': 'everyone',
#    'conversation_id': '1079957943263678465',
#    'text': 'Happy New Years Friends!!! ✌️Let Us Know What You’d Like!! 🍻🚚🍾 Serving Until 2 am!! 👊#yycliving #yycsmallbusiness #yycnow #yyclocal #yycnewyearseve #newyear #newyearseve #calgary… https://t.co/mDxNbNuguL',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '1047238716790517760'},
#   {'public_metrics': {'retweet_count': 0,
#     'reply_count': 1,
#     'like_count': 1,
#     'quote_count': 0},
#    'lang': 'en',
#    'id': '1079957943263612928',
#    'reply_settings': 'everyone',
#    'conversation_id': '1079957943263612928',
#    'text': 'Just got my fucking nose ring ripped out of my fucking face',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '1628898210'},
#   {'public_metrics': {'retweet_count': 2599,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'entities': {'mentions': [{'start': 3,
#       'end': 18,
#       'username': 'mineifiwildout',
#       'id': '1614375631'}]},
#    'id': '1079957943263608832',
#    'reply_settings': 'everyone',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1079878206444818432'}],
#    'conversation_id': '1079957943263608832',
#    'text': 'RT @mineifiwildout: DUI twitter going the fuck in today',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '2220182820'},
#   {'entities': {'urls': [{'start': 41,
#       'end': 64,
#       'url': 'https://t.co/U0xVFm7BCP',
#       'expanded_url': 'https://www.instagram.com/p/BsFA4PfjkxB/?utm_source=ig_twitter_share&igshid=cjzjs7qz714i',
#       'display_url': 'instagram.com/p/BsFA4PfjkxB/…'}],
#     'hashtags': [{'start': 22, 'end': 35, 'tag': 'HappyNewYear'},
#      {'start': 36, 'end': 40, 'tag': 'NYE'}]},
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'id': '1079957943259463680',
#    'reply_settings': 'everyone',
#    'conversation_id': '1079957943259463680',
#    'text': "Happy New Year y'all! #HappyNewYear #NYE https://t.co/U0xVFm7BCP",
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '50785833'},
#   {'entities': {'urls': [{'start': 45,
#       'end': 68,
#       'url': 'https://t.co/JsEJuAHt9Y',
#       'expanded_url': 'https://twitter.com/ufc/status/1079869667265540096',
#       'display_url': 'twitter.com/ufc/status/107…'}],
#     'mentions': [{'start': 3,
#       'end': 19,
#       'username': 'TheNotoriousMMA',
#       'id': '369583954'}]},
#    'public_metrics': {'retweet_count': 779,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'id': '1079957943259418624',
#    'reply_settings': 'everyone',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1079919372444073985'}],
#    'conversation_id': '1079957943259418624',
#    'text': 'RT @TheNotoriousMMA: Keep their heads ringin https://t.co/JsEJuAHt9Y',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '743186535558811648'},
#   {'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 1,
#     'quote_count': 0},
#    'lang': 'en',
#    'id': '1079957943246827521',
#    'reply_settings': 'everyone',
#    'conversation_id': '1079957943246827521',
#    'text': 'oh mt go',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '1061670446704349184'},
#   {'entities': {'hashtags': [{'start': 93, 'end': 104, 'tag': 'SimplyKpop'},
#      {'start': 105, 'end': 113, 'tag': 'Chungha'},
#      {'start': 114, 'end': 117, 'tag': '청하'},
#      {'start': 118, 'end': 133, 'tag': 'WhyDontYouKnow'},
#      {'start': 134, 'end': 139, 'tag': 'kpop'}],
#     'annotations': [{'start': 61,
#       'end': 67,
#       'probability': 0.5148,
#       'type': 'Person',
#       'normalized_text': 'Chungha'}],
#     'mentions': [{'start': 3,
#       'end': 15,
#       'username': '_Simplykpop',
#       'id': '505587119'}]},
#    'public_metrics': {'retweet_count': 77,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'id': '1079957943246712835',
#    'reply_settings': 'everyone',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1079920142132355072'}],
#    'conversation_id': '1079957943246712835',
#    'text': "RT @_Simplykpop: [The Most Highlighted K-Pop Artist of 2018] Chungha(청하)_Why Don't You Know\n\n#SimplyKpop #Chungha #청하 #WhyDontYouKnow #kpop…",
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '899265254466531329'},
#   {'in_reply_to_user_id': '1544575740',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'entities': {'mentions': [{'start': 0,
#       'end': 10,
#       'username': 'niceupdog',
#       'id': '1544575740'}]},
#    'id': '1079957943242682374',
#    'reply_settings': 'everyone',
#    'referenced_tweets': [{'type': 'replied_to', 'id': '1079851315562512384'}],
#    'conversation_id': '1079851315562512384',
#    'text': "@niceupdog Can't forget to always get this bread",
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '951572899713961984'},
#   {'public_metrics': {'retweet_count': 24,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'entities': {'annotations': [{'start': 83,
#       'end': 84,
#       'probability': 0.9342,
#       'type': 'Place',
#       'normalized_text': 'US'}],
#     'mentions': [{'start': 3,
#       'end': 16,
#       'username': 'peter_dutton',
#       'id': '1329766236'}]},
#    'id': '1079957943230128129',
#    'reply_settings': 'everyone',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1079722536508768256'}],
#    'conversation_id': '1079957943230128129',
#    'text': 'RT @peter_dutton: The huge new Pacific trade deal has gone into effect without the US...for both narrow economic interests and broader geos…',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '346029728'},
#   {'entities': {'urls': [{'start': 79,
#       'end': 102,
#       'url': 'https://t.co/Xax8ARuxkT',
#       'expanded_url': 'https://twitter.com/NYRE/status/1079941488451117057/photo/1',
#       'display_url': 'pic.twitter.com/Xax8ARuxkT'}],
#     'hashtags': [{'start': 30, 'end': 40, 'tag': 'RockinEve'}],
#     'mentions': [{'start': 63,
#       'end': 78,
#       'username': 'Camila_Cabello',
#       'id': '739784130'}]},
#    'public_metrics': {'retweet_count': 409,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'id': '1079957943221669889',
#    'reply_settings': 'everyone',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1079941488451117057'}],
#    'conversation_id': '1079957943221669889',
#    'text': 'RT @NYRE: Me dancing to these #RockinEve performances like...💃 @Camila_Cabello https://t.co/Xax8ARuxkT',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '2607125666'},
#   {'entities': {'urls': [{'start': 30,
#       'end': 53,
#       'url': 'https://t.co/B9D6bmx55f',
#       'expanded_url': 'https://www.instagram.com/p/BsFALJKneGfjt7vX22bjwm_eD9SC6ggw-gCb5c0/?utm_source=ig_twitter_share&igshid=v1bochrtzxdu',
#       'display_url': 'instagram.com/p/BsFALJKneGfj…'}]},
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'id': '1079957943221661696',
#    'reply_settings': 'everyone',
#    'conversation_id': '1079957943221661696',
#    'text': 'Going 2019 be Super Star✨⭐🌟✳️ https://t.co/B9D6bmx55f',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '221275383'},
#   {'entities': {'urls': [{'start': 189,
#       'end': 212,
#       'url': 'https://t.co/ufetYzy9Tf',
#       'expanded_url': 'https://twitter.com/RBesvinick/status/1079957943221657601/photo/1',
#       'display_url': 'pic.twitter.com/ufetYzy9Tf'}],
#     'hashtags': [{'start': 30, 'end': 38, 'tag': 'newyear'},
#      {'start': 67, 'end': 76, 'tag': 'selfcare'},
#      {'start': 77, 'end': 82, 'tag': 'love'},
#      {'start': 83, 'end': 93, 'tag': 'gratitude'},
#      {'start': 145, 'end': 153, 'tag': 'twitter'}]},
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'id': '1079957943221657601',
#    'reply_settings': 'everyone',
#    'conversation_id': '1079957943221657601',
#    'text': 'The best way to celebrate the #newyear and treat yourself right? \n\n#selfcare #love #gratitude\n\nHappy 2019 to friends, family, and this wonderful #twitter community that I’ve grown to love! https://t.co/ufetYzy9Tf',
#    'geo': {'place_id': '0064b4f401ced97c'},
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '971820815858720768'},
#   {'in_reply_to_user_id': '1000214682530074624',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'entities': {'mentions': [{'start': 0,
#       'end': 15,
#       'username': 'B_hundred_Hyun',
#       'id': '1000214682530074624'}]},
#    'id': '1079957943217401857',
#    'reply_settings': 'everyone',
#    'referenced_tweets': [{'type': 'replied_to', 'id': '1079774130709323777'}],
#    'conversation_id': '1079774130709323777',
#    'text': '@B_hundred_Hyun Happy new year oppa. Wish you all the best in this year. Saranghae. 😘',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '983646424213553153'},
#   {'entities': {'urls': [{'start': 67,
#       'end': 90,
#       'url': 'https://t.co/KvmM50zcBz',
#       'expanded_url': 'https://twitter.com/ShashiTharoor/status/1079750693198708738/photo/1',
#       'display_url': 'pic.twitter.com/KvmM50zcBz'}],
#     'annotations': [{'start': 43,
#       'end': 46,
#       'probability': 0.4711,
#       'type': 'Person',
#       'normalized_text': 'Modi'}],
#     'mentions': [{'start': 3,
#       'end': 17,
#       'username': 'ShashiTharoor',
#       'id': '24705126'}]},
#    'public_metrics': {'retweet_count': 2307,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'id': '1079957943217381376',
#    'reply_settings': 'everyone',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1079750693198708738'}],
#    'conversation_id': '1079957943217381376',
#    'text': 'RT @ShashiTharoor: Everyone dreads another Modi Midnight Surprise! https://t.co/KvmM50zcBz',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '469477241'},
#   {'entities': {'urls': [{'start': 43,
#       'end': 66,
#       'url': 'https://t.co/kIVXyJ3oDr',
#       'expanded_url': 'https://www.instagram.com/p/BsFBYPShhjg/?utm_source=ig_twitter_share&igshid=y55m9u4ne3hi',
#       'display_url': 'instagram.com/p/BsFBYPShhjg/…'}]},
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'id': '1079957943213264897',
#    'reply_settings': 'everyone',
#    'conversation_id': '1079957943213264897',
#    'text': '2019. A year for self love and no regrets. https://t.co/kIVXyJ3oDr',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '48706846'},
#   {'public_metrics': {'retweet_count': 0,
#     'reply_count': 1,
#     'like_count': 2,
#     'quote_count': 0},
#    'lang': 'en',
#    'id': '1079957943200763905',
#    'reply_settings': 'everyone',
#    'conversation_id': '1079957943200763905',
#    'text': 'listen. heres the thing. the new year is in 30 mins but i want to go to bed Now',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '3039983973'},
#   {'entities': {'hashtags': [{'start': 57, 'end': 64, 'tag': 'basics'}],
#     'annotations': [{'start': 22,
#       'end': 26,
#       'probability': 0.9195,
#       'type': 'Organization',
#       'normalized_text': 'Colts'}]},
#    'public_metrics': {'retweet_count': 1,
#     'reply_count': 0,
#     'like_count': 2,
#     'quote_count': 0},
#    'lang': 'en',
#    'id': '1079957943188160513',
#    'reply_settings': 'everyone',
#    'conversation_id': '1079957943188160513',
#    'text': 'Yo I fucking love the Colts and fuck anyone that doesn’t #basics',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '80643144'},
#   {'public_metrics': {'retweet_count': 440,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'entities': {'annotations': [{'start': 23,
#       'end': 34,
#       'probability': 0.3032,
#       'type': 'Person',
#       'normalized_text': 'Terese Agnew'}],
#     'mentions': [{'start': 3,
#       'end': 14,
#       'username': 'womensart1',
#       'id': '4823705386'}]},
#    'id': '1079957943187980288',
#    'reply_settings': 'everyone',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1079269208226230272'}],
#    'conversation_id': '1079957943187980288',
#    'text': "RT @womensart1: Artist Terese Agnew’s 'Portrait of a Textile Worker',  2005, constructed from 30,000 clothing labels stitched together over…",
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '886113401511923712'},
#   {'entities': {'urls': [{'start': 62,
#       'end': 85,
#       'url': 'https://t.co/ASKthMmnGX',
#       'expanded_url': 'http://naver.me/5obLgMEI',
#       'display_url': 'naver.me/5obLgMEI'},
#      {'start': 86,
#       'end': 109,
#       'url': 'https://t.co/RlPFCqMmZr',
#       'expanded_url': 'http://naver.me/GIv0nkR2',
#       'display_url': 'naver.me/GIv0nkR2'}],
#     'annotations': [{'start': 46,
#       'end': 56,
#       'probability': 0.8883,
#       'type': 'Person',
#       'normalized_text': 'JAEMIN JENO'}],
#     'mentions': [{'start': 3,
#       'end': 18,
#       'username': 'nctinformation',
#       'id': '1272175411737354242'},
#      {'start': 111, 'end': 121, 'username': 'NCTsmtown', 'id': '4811011050'},
#      {'start': 122,
#       'end': 138,
#       'username': 'NCTsmtown_DREAM',
#       'id': '870188817537355776'}]},
#    'public_metrics': {'retweet_count': 94,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'id': '1079957943179632641',
#    'reply_settings': 'everyone',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1079946114957099008'}],
#    'conversation_id': '1079957943179632641',
#    'text': 'RT @nctinformation: 190101 Tarot reading with JAEMIN JENO (1)\nhttps://t.co/ASKthMmnGX\nhttps://t.co/RlPFCqMmZr\n\n@NCTsmtown\n@NCTsmtown_DREAM…',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '1027143879336718336'},
#   {'public_metrics': {'retweet_count': 1,
#     'reply_count': 0,
#     'like_count': 2,
#     'quote_count': 0},
#    'lang': 'en',
#    'id': '1079957943179571200',
#    'reply_settings': 'everyone',
#    'conversation_id': '1079957943179571200',
#    'text': "Let's start a trend, how about we start reporting anyone suspicious of drunk driving to 911 all of 2019, because fuck them.",
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '2225890519'},
#   {'in_reply_to_user_id': '57841792',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'entities': {'mentions': [{'start': 0,
#       'end': 10,
#       'username': 'GavinFree',
#       'id': '57841792'},
#      {'start': 21, 'end': 31, 'username': 'GavinFree', 'id': '57841792'}]},
#    'id': '1079957943171325952',
#    'reply_settings': 'everyone',
#    'referenced_tweets': [{'type': 'replied_to', 'id': '1079879323476209664'}],
#    'conversation_id': '1079879323476209664',
#    'text': '@GavinFree Good luck @GavinFree and best of wishes into 2019.',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '2171061205'},
#   {'in_reply_to_user_id': '1481884207',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 1,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'in',
#    'entities': {'mentions': [{'start': 0,
#       'end': 14,
#       'username': 'samsinardilah',
#       'id': '1481884207'}]},
#    'id': '1079957943171174401',
#    'reply_settings': 'everyone',
#    'referenced_tweets': [{'type': 'replied_to', 'id': '1079928627167260672'}],
#    'conversation_id': '1079928627167260672',
#    'text': '@samsinardilah Wow.. "awak"',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '1328310306'},
#   {'public_metrics': {'retweet_count': 100,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'entities': {'annotations': [{'start': 22,
#       'end': 29,
#       'probability': 0.5043,
#       'type': 'Product',
#       'normalized_text': 'Facebook'},
#      {'start': 40,
#       'end': 47,
#       'probability': 0.7637,
#       'type': 'Place',
#       'normalized_text': 'Marriott'},
#      {'start': 61,
#       'end': 75,
#       'probability': 0.4155,
#       'type': 'Place',
#       'normalized_text': 'British Airways'},
#      {'start': 86,
#       'end': 90,
#       'probability': 0.4913,
#       'type': 'Organization',
#       'normalized_text': 'Quora'}],
#     'mentions': [{'start': 3,
#       'end': 9,
#       'username': 'WIRED',
#       'id': '1344951'}]},
#    'id': '1079957943167213574',
#    'reply_settings': 'everyone',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1079914863730876418'}],
#    'conversation_id': '1079957943167213574',
#    'text': 'RT @WIRED: If you use Facebook, stay in Marriott hotels, fly British Airways, post on Quora, or, well, use the internet, read this list. An…',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '2515790353'},
#   {'in_reply_to_user_id': '4691008230',
#    'entities': {'urls': [{'start': 34,
#       'end': 57,
#       'url': 'https://t.co/7FqkHUkEPo',
#       'expanded_url': 'https://twitter.com/10jayg/status/1079957943162978305/photo/1',
#       'display_url': 'pic.twitter.com/7FqkHUkEPo'}],
#     'mentions': [{'start': 0,
#       'end': 16,
#       'username': 'lisamarieheartt',
#       'id': '4691008230'}]},
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'id': '1079957943162978305',
#    'reply_settings': 'everyone',
#    'referenced_tweets': [{'type': 'replied_to', 'id': '1079926270383640576'}],
#    'conversation_id': '1079926270383640576',
#    'text': '@lisamarieheartt Happy New Year 🎆 https://t.co/7FqkHUkEPo',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '2292129158'},
#   {'entities': {'urls': [{'start': 246,
#       'end': 269,
#       'url': 'https://t.co/8oUKAiQvot',
#       'expanded_url': 'https://pin.it/uz6kvegc6orvij',
#       'display_url': 'pin.it/uz6kvegc6orvij'}],
#     'mentions': [{'start': 123,
#       'end': 137,
#       'username': 'NiceAnology24',
#       'id': '1332806532'},
#      {'start': 138, 'end': 149, 'username': 'torikickit', 'id': '363430529'},
#      {'start': 150, 'end': 163, 'username': 'CamillaIluna', 'id': '82418724'},
#      {'start': 164, 'end': 172, 'username': 'kayladz', 'id': '143592990'},
#      {'start': 173, 'end': 186, 'username': 'JessicaCaban', 'id': '18905800'},
#      {'start': 187,
#       'end': 203,
#       'username': 'mrEricHernandez',
#       'id': '243206374'},
#      {'start': 204, 'end': 215, 'username': 'philsmeeze', 'id': '47532218'},
#      {'start': 234, 'end': 244, 'username': 'BrunoMars', 'id': '100220864'}]},
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 1,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'id': '1079957943158743042',
#    'reply_settings': 'everyone',
#    'conversation_id': '1079957943158743042',
#    'text': '🎉🌟HAPPY NEW YEAR🌟💖2 ALL HOOLIGAN FRIENDS&amp;FAMILY WISH U A GR8🎶2019🎶🎅SENDING U LOVE💖🕊 PEACE&amp;SOUL🎈🎉🎂❤💚💜💙💛🐼\nESPECIALLY @NiceAnology24 @torikickit\n@CamillaIluna @kayladz @JessicaCaban\n@mrEricHernandez\n@philsmeeze the guys💖\nMR SEXY @BrunoMars\n\nhttps://t.co/8oUKAiQvot',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '119545553'},
#   {'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 1,
#     'quote_count': 0},
#    'lang': 'en',
#    'id': '1079957943154561024',
#    'reply_settings': 'everyone',
#    'conversation_id': '1079957943154561024',
#    'text': 'lol i’m sick of everything',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '222251855'},
#   {'public_metrics': {'retweet_count': 153,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'id': '1079957943150354432',
#    'reply_settings': 'everyone',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1079931043765866496'}],
#    'conversation_id': '1079957943150354432',
#    'text': 'RT @Pantecoco: Hail Sacred heart dear College\nOur fountain of wisdom clear\nWe loudly sing your praises\nAnd raise our flags of red and white.',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '769344085735968768'},
#   {'entities': {'urls': [{'start': 34,
#       'end': 57,
#       'url': 'https://t.co/3aEF5FM5cD',
#       'expanded_url': 'https://twitter.com/Cristiano/status/1079868531125219329/photo/1',
#       'display_url': 'pic.twitter.com/3aEF5FM5cD'}],
#     'mentions': [{'start': 3,
#       'end': 13,
#       'username': 'Cristiano',
#       'id': '155659213'}]},
#    'public_metrics': {'retweet_count': 20548,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'id': '1079957943150202880',
#    'reply_settings': 'everyone',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1079868531125219329'}],
#    'conversation_id': '1079957943150202880',
#    'text': 'RT @Cristiano: Happy New Year!🎆❤️ https://t.co/3aEF5FM5cD',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '878840041459531776'},
#   {'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'id': '1079957943141818368',
#    'reply_settings': 'everyone',
#    'conversation_id': '1079957943141818368',
#    'text': 'Hang oveeeeeeer',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '570108401'},
#   {'entities': {'urls': [{'start': 51,
#       'end': 74,
#       'url': 'https://t.co/jQqfjwN5xQ',
#       'expanded_url': 'https://goo.gl/fbjqgp',
#       'display_url': 'goo.gl/fbjqgp'}],
#     'mentions': [{'start': 78,
#       'end': 93,
#       'username': 'Walking_Da_Dog',
#       'id': '484112092'}]},
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'id': '1079957943121076224',
#    'reply_settings': 'everyone',
#    'conversation_id': '1079957943121076224',
#    'text': 'Nothing beats redfish on topwater in the shallows! https://t.co/jQqfjwN5xQ RT @Walking_Da_Dog',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '300830714'},
#   {'entities': {'urls': [{'start': 91,
#       'end': 114,
#       'url': 'https://t.co/K3iBoyUh42',
#       'expanded_url': 'http://WBKO.com',
#       'display_url': 'WBKO.com'},
#      {'start': 135,
#       'end': 158,
#       'url': 'https://t.co/ObCAai7TJp',
#       'expanded_url': 'https://twitter.com/ChrisAllenSkywx/status/1079957943116812288/photo/1',
#       'display_url': 'pic.twitter.com/ObCAai7TJp'}],
#     'hashtags': [{'start': 115, 'end': 122, 'tag': 'wbkowx'},
#      {'start': 123, 'end': 128, 'tag': 'wbko'},
#      {'start': 129, 'end': 134, 'tag': 'kywx'}]},
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'id': '1079957943116812288',
#    'reply_settings': 'everyone',
#    'conversation_id': '1079957943116812288',
#    'text': 'Automatic DopplerMAX Radar December 31, 2018 at 10:30PM Always on the WBKO Weather App and https://t.co/K3iBoyUh42 #wbkowx #wbko #kywx https://t.co/ObCAai7TJp',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '17131327'},
#   {'entities': {'urls': [{'start': 34,
#       'end': 57,
#       'url': 'https://t.co/3aEF5FM5cD',
#       'expanded_url': 'https://twitter.com/Cristiano/status/1079868531125219329/photo/1',
#       'display_url': 'pic.twitter.com/3aEF5FM5cD'}],
#     'mentions': [{'start': 3,
#       'end': 13,
#       'username': 'Cristiano',
#       'id': '155659213'}]},
#    'public_metrics': {'retweet_count': 20548,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'id': '1079957943112523776',
#    'reply_settings': 'everyone',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1079868531125219329'}],
#    'conversation_id': '1079957943112523776',
#    'text': 'RT @Cristiano: Happy New Year!🎆❤️ https://t.co/3aEF5FM5cD',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '3193385020'},
#   {'entities': {'urls': [{'start': 95,
#       'end': 118,
#       'url': 'https://t.co/2ATqBtaWM9',
#       'expanded_url': 'https://twitter.com/AndySlow/status/1079496737352499207/video/1',
#       'display_url': 'pic.twitter.com/2ATqBtaWM9'}],
#     'annotations': [{'start': 14,
#       'end': 28,
#       'probability': 0.9905,
#       'type': 'Person',
#       'normalized_text': 'Raheem Sterling'}],
#     'mentions': [{'start': 3,
#       'end': 12,
#       'username': 'AndySlow',
#       'id': '77444282'},
#      {'start': 84, 'end': 94, 'username': 'sterling7', 'id': '627491854'}]},
#    'public_metrics': {'retweet_count': 41202,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'id': '1079957943108493312',
#    'reply_settings': 'everyone',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1079496737352499207'}],
#    'conversation_id': '1079957943108493312',
#    'text': 'RT @AndySlow: Raheem Sterling’s 1 year old son already has unbelievable technique 👏 @sterling7 https://t.co/2ATqBtaWM9',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '1046816862'},
#   {'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'id': '1079957943099879424',
#    'reply_settings': 'everyone',
#    'conversation_id': '1079957943099879424',
#    'text': 'Something huge is gonna happen',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '3932928678'},
#   {'public_metrics': {'retweet_count': 6449,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'entities': {'mentions': [{'start': 3,
#       'end': 16,
#       'username': 'ThomasSowell',
#       'id': '57338175'}]},
#    'id': '1079957943095910402',
#    'reply_settings': 'everyone',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1079437712480972800'}],
#    'conversation_id': '1079957943095910402',
#    'text': 'RT @ThomasSowell: "If you want to see the poor remain poor, generation after generation, just keep the standards low in their schools and m…',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '2575230326'},
#   {'entities': {'urls': [{'start': 106,
#       'end': 129,
#       'url': 'https://t.co/kM3li1HZbd',
#       'expanded_url': 'https://nextshark.com/angelababy-assistant-shoes/',
#       'display_url': 'nextshark.com/angelababy-ass…'}]},
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'id': '1079957943095824386',
#    'reply_settings': 'everyone',
#    'conversation_id': '1079957943095824386',
#    'text': 'Viral Photo of Angelababy’s Assistant Allegedly Kneeling to Take Her Shoes Off Draws Outrage entrepreneur https://t.co/kM3li1HZbd',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '866276485799317504'},
#   {'entities': {'urls': [{'start': 61,
#       'end': 84,
#       'url': 'https://t.co/PbWaxQ71IB',
#       'expanded_url': 'https://twitter.com/sinha_romil/status/1079956553577496577/photo/1',
#       'display_url': 'pic.twitter.com/PbWaxQ71IB'}],
#     'mentions': [{'start': 3,
#       'end': 15,
#       'username': 'sinha_romil',
#       'id': '989731499476856832'}]},
#    'public_metrics': {'retweet_count': 13,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'id': '1079957943095676928',
#    'reply_settings': 'everyone',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1079956553577496577'}],
#    'conversation_id': '1079957943095676928',
#    'text': 'RT @sinha_romil: When you see his dick for the first time !🙃 https://t.co/PbWaxQ71IB',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '957194691316862976'},
#   {'entities': {'urls': [{'start': 92,
#       'end': 115,
#       'url': 'https://t.co/zyjzKFYPq1',
#       'expanded_url': 'https://twitter.com/TheNotoriousMMA/status/1079932795554856962/photo/1',
#       'display_url': 'pic.twitter.com/zyjzKFYPq1'}],
#     'hashtags': [{'start': 83, 'end': 91, 'tag': 'Forbesy'}],
#     'mentions': [{'start': 3,
#       'end': 19,
#       'username': 'TheNotoriousMMA',
#       'id': '369583954'}]},
#    'public_metrics': {'retweet_count': 2940,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'lang': 'en',
#    'id': '1079957943087452160',
#    'reply_settings': 'everyone',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1079932795554856962'}],
#    'conversation_id': '1079957943087452160',
#    'text': 'RT @TheNotoriousMMA: That 9 milli won’t keep you on top of my list for long, kid. \n#Forbesy https://t.co/zyjzKFYPq1',
#    'created_at': '2019-01-01T04:30:12.000Z',
#    'author_id': '2227388943'},
#   {'in_reply_to_user_id': '967027984426242053',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 1,
#     'quote_count': 0},
#    'lang': 'en',
#    'entities': {'annotations': [{'start': 68,
#       'end': 71,
#       'probability': 0.8915,
#       'type': 'Person',
#       'normalized_text': 'Fred'}],
#     'mentions': [{'start': 0,
#       'end': 16,
#       'username': 'fred_guttenberg',
#       'id': '967027984426242053'}]},
#    'id': '1079957943083257857',
#    'reply_settings': 'everyone',
#    'referenced_tweets': [{'type': 'replied_to', 'id': '1079933705060343809'}],
#    'conversation_id': '1079933705060343809',
#    'text': '@fred_guttenberg I want to hold you and love you into this new year Fred. (Former long term care giver). My heart is with your heart.',
# ...
#    'lang': 'en',
#    'reply_settings': 'everyone',
#    'conversation_id': '1080287695107182592',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1080287695107182592',
#    'created_at': '2019-01-02T02:20:31.000Z'},
#   {'entities': {'urls': [{'start': 103,
#       'end': 126,
#       'url': 'https://t.co/bE9QI52gPd',
#       'expanded_url': 'http://www.crowdfireapp.com/?r=td',
#       'display_url': 'crowdfireapp.com/?r=td'}]},
#    'author_id': '284118113',
#    'text': '1 new follower in the last day and it is more than just stats, I use it for growing my account! Try it https://t.co/bE9QI52gPd',
#    'lang': 'en',
#    'reply_settings': 'everyone',
#    'conversation_id': '1080287695090470912',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1080287695090470912',
#    'created_at': '2019-01-02T02:20:31.000Z'},
#   {'entities': {'urls': [{'start': 64,
#       'end': 87,
#       'url': 'https://t.co/KXgaQzGm0W',
#       'expanded_url': 'https://twitter.com/aasdanny/status/1080265021953884162/video/1',
#       'display_url': 'pic.twitter.com/KXgaQzGm0W'}],
#     'mentions': [{'start': 3,
#       'end': 12,
#       'username': 'aasdanny',
#       'id': '15649405'}],
#     'hashtags': [{'start': 56, 'end': 63, 'tag': 'HookEm'}],
#     'annotations': [{'start': 14,
#       'end': 17,
#       'probability': 0.585,
#       'type': 'Person',
#       'normalized_text': 'Bevo'}]},
#    'author_id': '346756634',
#    'text': 'RT @aasdanny: Bevo is not here for this mascot meeting. #HookEm https://t.co/KXgaQzGm0W',
#    'lang': 'en',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1080265021953884162'}],
#    'reply_settings': 'everyone',
#    'conversation_id': '1080287695086211072',
#    'public_metrics': {'retweet_count': 15852,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1080287695086211072',
#    'created_at': '2019-01-02T02:20:31.000Z'},
#   {'author_id': '3863402413',
#    'text': 'RT @BadgrGrl21: You know LAPD is in cahoots with Co$.  They get money from them, then looks other way...  #ScientologyTheAftermath',
#    'lang': 'en',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1080269508768657408'}],
#    'reply_settings': 'everyone',
#    'entities': {'mentions': [{'start': 3,
#       'end': 14,
#       'username': 'BadgrGrl21',
#       'id': '168935461'}],
#     'hashtags': [{'start': 106, 'end': 130, 'tag': 'ScientologyTheAftermath'}],
#     'annotations': [{'start': 25,
#       'end': 28,
#       'probability': 0.4928,
#       'type': 'Organization',
#       'normalized_text': 'LAPD'}]},
#    'conversation_id': '1080287695077806080',
#    'public_metrics': {'retweet_count': 1,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1080287695077806080',
#    'created_at': '2019-01-02T02:20:31.000Z'},
#   {'entities': {'urls': [{'start': 200,
#       'end': 223,
#       'url': 'https://t.co/7ajCpysg18',
#       'expanded_url': 'http://www.guybone.com/list_sale_videos.php',
#       'display_url': 'guybone.com/list_sale_vide…'},
#      {'start': 274,
#       'end': 297,
#       'url': 'https://t.co/T4F33xvAax',
#       'expanded_url': 'https://twitter.com/GuyBoneMedia/status/1080287695077761024/photo/1',
#       'display_url': 'pic.twitter.com/T4F33xvAax'},
#      {'start': 274,
#       'end': 297,
#       'url': 'https://t.co/T4F33xvAax',
#       'expanded_url': 'https://twitter.com/GuyBoneMedia/status/1080287695077761024/photo/1',
#       'display_url': 'pic.twitter.com/T4F33xvAax'},
#      {'start': 274,
#       'end': 297,
#       'url': 'https://t.co/T4F33xvAax',
#       'expanded_url': 'https://twitter.com/GuyBoneMedia/status/1080287695077761024/photo/1',
#       'display_url': 'pic.twitter.com/T4F33xvAax'},
#      {'start': 274,
#       'end': 297,
#       'url': 'https://t.co/T4F33xvAax',
#       'expanded_url': 'https://twitter.com/GuyBoneMedia/status/1080287695077761024/photo/1',
#       'display_url': 'pic.twitter.com/T4F33xvAax'}]},
#    'author_id': '379337465',
#    'text': "MASSIVE SAVINGS Dec 31 &amp; Jan 1 ONLY! ⌛️\nDon't miss out! ⏲️\nStreaming Subscriptions HALF OFF! Keep sale price til you cancel! 💰\nDownload to Own Scenes cheapest they've been in ages $3.95 each!!! 🤯\nhttps://t.co/7ajCpysg18\nSPREAD THE WORD!!! 📢\nHAPPY NEW YEAR FROM GUYBONE! https://t.co/T4F33xvAax",
#    'lang': 'en',
#    'reply_settings': 'everyone',
#    'conversation_id': '1080287695077761024',
#    'public_metrics': {'retweet_count': 1,
#     'reply_count': 0,
#     'like_count': 2,
#     'quote_count': 0},
#    'id': '1080287695077761024',
#    'created_at': '2019-01-02T02:20:31.000Z'},
#   {'author_id': '223405179',
#    'text': '@Dollyyymangoo Lmaoo niggas can’t move on? 😭',
#    'lang': 'en',
#    'referenced_tweets': [{'type': 'replied_to', 'id': '1080286527639277570'}],
#    'reply_settings': 'everyone',
#    'conversation_id': '1080281118987804672',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'in_reply_to_user_id': '770714167879892992',
#    'id': '1080287695077699584',
#    'created_at': '2019-01-02T02:20:31.000Z'},
#   {'entities': {'urls': [{'start': 42,
#       'end': 65,
#       'url': 'https://t.co/B5EHZ9Xav0',
#       'expanded_url': 'https://twitter.com/hot_pcy_pict/status/1079663197974495233/video/1',
#       'display_url': 'pic.twitter.com/B5EHZ9Xav0'}],
#     'mentions': [{'start': 3,
#       'end': 16,
#       'username': 'hot_pcy_pict',
#       'id': '3238990975'}],
#     'annotations': [{'start': 18,
#       'end': 30,
#       'probability': 0.9466,
#       'type': 'Person',
#       'normalized_text': 'Park Chanyeol'}]},
#    'author_id': '856496380352712704',
#    'text': 'RT @hot_pcy_pict: Park Chanyeol everyone😂 https://t.co/B5EHZ9Xav0',
#    'lang': 'en',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1079663197974495233'}],
#    'reply_settings': 'everyone',
#    'conversation_id': '1080287695069417472',
#    'public_metrics': {'retweet_count': 2239,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1080287695069417472',
#    'created_at': '2019-01-02T02:20:31.000Z'},
#   {'author_id': '1434631531',
#    'text': 'This Tweet from @Lovevanessaax has been withheld in: Germany.',
#    'withheld': {'copyright': True, 'country_codes': ['XY'], 'scope': 'tweet'},
#    'lang': 'en',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1080182755449888768'}],
#    'reply_settings': 'everyone',
#    'conversation_id': '1080287695065178113',
#    'public_metrics': {'retweet_count': 200526,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1080287695065178113',
#    'created_at': '2019-01-02T02:20:31.000Z'},
#   {'author_id': '348203861',
#    'text': 'RT @LadyBond8: HAPPY NEW YEAR !!!🎵🎄🎇🌠🎉🥂🎂🤗🎆🌹💖🎵🎇🌠 MAY THIS YEAR BRINGS YOU HAPPINESS, LOVE AND BLESSINGS! 🎈🌹💖 THANK YOU EVERYONE! I APPRECIAT…',
#    'lang': 'en',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1080033509169758208'}],
#    'reply_settings': 'everyone',
#    'entities': {'mentions': [{'start': 3,
#       'end': 13,
#       'username': 'LadyBond8',
#       'id': '859381748462899200'}]},
#    'conversation_id': '1080287695065083904',
#    'public_metrics': {'retweet_count': 130,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1080287695065083904',
#    'created_at': '2019-01-02T02:20:31.000Z'},
#   {'entities': {'urls': [{'start': 88,
#       'end': 111,
#       'url': 'https://t.co/g10bfiUEWU',
#       'expanded_url': 'https://twitter.com/MissPiggy/status/1080146664495742977/photo/1',
#       'display_url': 'pic.twitter.com/g10bfiUEWU'}],
#     'mentions': [{'start': 3,
#       'end': 13,
#       'username': 'MissPiggy',
#       'id': '785739140'}]},
#    'author_id': '4852002231',
#    'text': "RT @MissPiggy: New Year, New Moi? HA!! As if. If it ain't broke, don't fix it, sweetie. https://t.co/g10bfiUEWU",
#    'lang': 'en',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1080146664495742977'}],
#    'reply_settings': 'everyone',
#    'conversation_id': '1080287695061110784',
#    'public_metrics': {'retweet_count': 12056,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1080287695061110784',
#    'created_at': '2019-01-02T02:20:31.000Z'},
#   {'author_id': '902353171',
#    'text': 'RT @RedTRaccoon: Getting myself squared away is a resolution this year too, so saying something to 140k people is a way for me to be motiva…',
#    'lang': 'en',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1080259299430014976'}],
#    'reply_settings': 'everyone',
#    'entities': {'mentions': [{'start': 3,
#       'end': 15,
#       'username': 'RedTRaccoon',
#       'id': '825518870421180416'}]},
#    'conversation_id': '1080287695061086209',
#    'public_metrics': {'retweet_count': 15,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1080287695061086209',
#    'created_at': '2019-01-02T02:20:31.000Z'},
#   {'author_id': '1703355536',
#    'text': 'RT @ChronicPocket: I still don’t know why it hurts when you bite your tongue on accident but it doesn’t hurt when you bite it on purpose. I…',
#    'lang': 'en',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1080014363258318848'}],
#    'reply_settings': 'everyone',
#    'entities': {'mentions': [{'start': 3,
#       'end': 17,
#       'username': 'chronicpocket',
#       'id': '1098609761514221568'}]},
#    'conversation_id': '1080287695052701698',
#    'public_metrics': {'retweet_count': 43,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1080287695052701698',
#    'created_at': '2019-01-02T02:20:31.000Z'},
#   {'author_id': '26632983',
#    'text': 'RT @LexBunny: As a person who has seen both Bruno Mars and Beyonce perform in the last three months I’m gonna say it.\n \nBruno Mars is the b…',
#    'lang': 'en',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1080014740494049280'}],
#    'reply_settings': 'everyone',
#    'entities': {'mentions': [{'start': 3,
#       'end': 12,
#       'username': 'LexBunny',
#       'id': '25324582'}],
#     'annotations': [{'start': 44,
#       'end': 53,
#       'probability': 0.9933,
#       'type': 'Person',
#       'normalized_text': 'Bruno Mars'},
#      {'start': 59,
#       'end': 65,
#       'probability': 0.9947,
#       'type': 'Person',
#       'normalized_text': 'Beyonce'},
#      {'start': 120,
#       'end': 129,
#       'probability': 0.9428,
#       'type': 'Person',
#       'normalized_text': 'Bruno Mars'}]},
#    'conversation_id': '1080287695040065536',
#    'public_metrics': {'retweet_count': 61,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1080287695040065536',
#    'created_at': '2019-01-02T02:20:31.000Z'},
#   {'author_id': '852047733699395584',
#    'text': 'hello how is your 2019',
#    'lang': 'en',
#    'reply_settings': 'everyone',
#    'conversation_id': '1080287695040057344',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1080287695040057344',
#    'created_at': '2019-01-02T02:20:31.000Z'},
#   {'author_id': '70317461',
#    'text': 'RT @skertskertt: She’s a queen with or without you.',
#    'lang': 'en',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1079830667280699392'}],
#    'reply_settings': 'everyone',
#    'entities': {'mentions': [{'start': 3,
#       'end': 15,
#       'username': 'skertskertt',
#       'id': '721738510151974912'}]},
#    'conversation_id': '1080287695035863042',
#    'public_metrics': {'retweet_count': 12892,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1080287695035863042',
#    'created_at': '2019-01-02T02:20:31.000Z'},
#   {'author_id': '195215365',
#    'text': 'RT @m_guidooo: Don’t forget to tell someone today that they in fact do matter... sometimes a person just needs to be reminded.',
#    'lang': 'en',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1080259721389584386'}],
#    'reply_settings': 'everyone',
#    'conversation_id': '1080287695023337472',
#    'public_metrics': {'retweet_count': 1,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1080287695023337472',
#    'created_at': '2019-01-02T02:20:31.000Z'},
#   {'author_id': '2173340067',
#    'text': 'Betray me it’s whatever',
#    'lang': 'en',
#    'reply_settings': 'everyone',
#    'conversation_id': '1080287695023292416',
#    'public_metrics': {'retweet_count': 0,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1080287695023292416',
#    'created_at': '2019-01-02T02:20:31.000Z'},
#   {'entities': {'urls': [{'start': 85,
#       'end': 108,
#       'url': 'https://t.co/anVvi6nNO6',
#       'expanded_url': 'https://twitter.com/Bucks/status/1080278095620378624/video/1',
#       'display_url': 'pic.twitter.com/anVvi6nNO6'}],
#     'mentions': [{'start': 3, 'end': 9, 'username': 'Bucks', 'id': '15900167'},
#      {'start': 15, 'end': 28, 'username': 'Giannis_An34', 'id': '2279776304'}],
#     'hashtags': [{'start': 72, 'end': 84, 'tag': 'FearTheDeer'}]},
#    'author_id': '486975435',
#    'text': 'RT @Bucks: Did @Giannis_An34 just throw down the POSTER OF THE YEAR!?!\n\n#FearTheDeer https://t.co/anVvi6nNO6',
#    'lang': 'en',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1080278095620378624'}],
#    'reply_settings': 'everyone',
#    'conversation_id': '1080287695023280128',
#    'public_metrics': {'retweet_count': 871,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1080287695023280128',
#    'created_at': '2019-01-02T02:20:31.000Z'},
#   {'entities': {'urls': [{'start': 43,
#       'end': 66,
#       'url': 'https://t.co/mNd2EPYGhN',
#       'expanded_url': 'https://twitter.com/nik__ai/status/1080062011331960834/photo/1',
#       'display_url': 'pic.twitter.com/mNd2EPYGhN'}]},
#    'author_id': '1071531610351263745',
#    'text': 'RT @nik__ai: accidental baby acquisition!! https://t.co/mNd2EPYGhN',
#    'lang': 'en',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1080062011331960834'}],
#    'reply_settings': 'everyone',
#    'conversation_id': '1080287695019147264',
#    'public_metrics': {'retweet_count': 8,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1080287695019147264',
#    'created_at': '2019-01-02T02:20:31.000Z'},
#   {'author_id': '323413118',
#    'text': 'RT @DilanTheVillain: Brent Faiyaz don’t get enough credit',
#    'lang': 'en',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1080238759893979137'}],
#    'reply_settings': 'everyone',
#    'entities': {'mentions': [{'start': 3,
#       'end': 19,
#       'username': 'DilanTheVillain',
#       'id': '143883533'}],
#     'annotations': [{'start': 21,
#       'end': 32,
#       'probability': 0.98,
#       'type': 'Person',
#       'normalized_text': 'Brent Faiyaz'}]},
#    'conversation_id': '1080287695019094016',
#    'public_metrics': {'retweet_count': 328,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1080287695019094016',
#    'created_at': '2019-01-02T02:20:31.000Z'},
#   {'entities': {'urls': [{'start': 51,
#       'end': 74,
#       'url': 'https://t.co/ksHoWQU6yQ',
#       'expanded_url': 'https://twitter.com/bestoflisa/status/1080273812250226688/photo/1',
#       'display_url': 'pic.twitter.com/ksHoWQU6yQ'},
#      {'start': 51,
#       'end': 74,
#       'url': 'https://t.co/ksHoWQU6yQ',
#       'expanded_url': 'https://twitter.com/bestoflisa/status/1080273812250226688/photo/1',
#       'display_url': 'pic.twitter.com/ksHoWQU6yQ'}],
#     'mentions': [{'start': 3,
#       'end': 14,
#       'username': 'bestoflisa',
#       'id': '808278577'}]},
#    'author_id': '754868125766516737',
#    'text': 'RT @bestoflisa: good morning to my precious one ❤️ https://t.co/ksHoWQU6yQ',
#    'lang': 'en',
#    'referenced_tweets': [{'type': 'retweeted', 'id': '1080273812250226688'}],
#    'reply_settings': 'everyone',
#    'conversation_id': '1080287695014846464',
#    'public_metrics': {'retweet_count': 285,
#     'reply_count': 0,
#     'like_count': 0,
#     'quote_count': 0},
#    'id': '1080287695014846464',
#    'created_at': '2019-01-02T02:20:31.000Z'},
#   ...]}

# %%
# Convert JSON tweets to DataFrame
data = [pd.json_normalize(allTweets_json['tweets'])]
df = pd.concat(data, axis=0, ignore_index=True)

# Parse datetime column to datetime
df.created_at = pd.to_datetime(df.created_at)
df
# Out:
#         in_reply_to_user_id lang                   id reply_settings  \
# 0       1021209821695991810   en  1079957943343144960       everyone
# 1        772925896130961408   en  1079957943334912000       everyone
# 2                       NaN   en  1079957943334899712       everyone
# 3                       NaN   en  1079957943330705409       everyone
# 4                       NaN   en  1079957943330627584       everyone
# ...                     ...  ...                  ...            ...
# 919524                  NaN   en  1437119038228926466       everyone
# 919525                  NaN   en  1437119038228865025       everyone
# 919526  1352321120368799852   en  1437119038224744449       everyone
# 919527                  NaN   en  1437119038220652551       everyone
# 919528                  NaN   en  1437119038220427264       everyone
#
#                                         referenced_tweets  \
# 0       [{'type': 'replied_to', 'id': '107995732227579...
# 1       [{'type': 'replied_to', 'id': '107995300863559...
# 2       [{'type': 'retweeted', 'id': '1079957890784481...
# 3       [{'type': 'retweeted', 'id': '1079280554560765...
# 4       [{'type': 'retweeted', 'id': '1079957919792353...
# ...                                                   ...
# 919524  [{'type': 'retweeted', 'id': '1437118272453885...
# 919525                                                NaN
# 919526  [{'type': 'replied_to', 'id': '143711889764425...
# 919527                                                NaN
# 919528  [{'type': 'retweeted', 'id': '1436988747254403...
#
#             conversation_id  \
# 0       1079710990441181185
# 1       1079953008635592704
# 2       1079957943334899712
# 3       1079957943330705409
# 4       1079957943330627584
# ...                     ...
# 919524  1437119038228926466
# 919525  1437119038228865025
# 919526  1437118897644257280
# 919527  1437119038220652551
# 919528  1437119038220427264
#
#                                                      text  \
# 0       @Panchin083 Hahahah i wuv you https://t.co/Z4H...
# 1       @ViciousRalph Why you doubt yourself? Figure o...
# 2       RT @tcm: Still struggling to find the perfect ...
# 3           RT @emilyxsnapp: fuck https://t.co/oBcfD6HPgj
# 4       RT @entwinedglobal: We wish you all a prospero...
# ...                                                   ...
# 919524  RT @EliseiNicole: #UK Manchester Parklife Fest...
# 919525  Yaqoob (ع) cried for 40 years even though Yous...
# 919526                @sopeoIogist outro  tear  is  yours
# 919527  Turn on Air-Con! The current temperature is 26...
# 919528  RT @Irwanxq: Dalam relationship ni tak perlu p...
#
#                       created_at            author_id  \
# 0      2019-01-01 04:30:12+00:00   989088763094732805
# 1      2019-01-01 04:30:12+00:00   954046885467246592
# 2      2019-01-01 04:30:12+00:00             28752714
# 3      2019-01-01 04:30:12+00:00            231199325
# 4      2019-01-01 04:30:12+00:00   809111804035104768
# ...                          ...                  ...
# 919524 2021-09-12 18:20:53+00:00            141679950
# 919525 2021-09-12 18:20:53+00:00           2199814184
# 919526 2021-09-12 18:20:53+00:00  1372615442993414144
# 919527 2021-09-12 18:20:53+00:00  1397006132460232705
# 919528 2021-09-12 18:20:53+00:00           1121296513
#
#                                             entities.urls  ...  \
# 0       [{'start': 30, 'end': 53, 'url': 'https://t.co...  ...
# 1                                                     NaN  ...
# 2                                                     NaN  ...
# 3       [{'start': 22, 'end': 45, 'url': 'https://t.co...  ...
# 4                                                     NaN  ...
# ...                                                   ...  ...
# 919524  [{'start': 80, 'end': 103, 'url': 'https://t.c...  ...
# 919525  [{'start': 194, 'end': 217, 'url': 'https://t....  ...
# 919526                                                NaN  ...
# 919527                                                NaN  ...
# 919528                                                NaN  ...
#
#                                         entities.mentions  \
# 0                                                     NaN
# 1                                                     NaN
# 2       [{'start': 3, 'end': 7, 'username': 'tcm', 'id...
# 3                                                     NaN
# 4       [{'start': 3, 'end': 18, 'username': 'entwined...
# ...                                                   ...
# 919524  [{'start': 3, 'end': 16, 'username': 'EliseiNi...
# 919525                                                NaN
# 919526  [{'start': 0, 'end': 12, 'username': 'sopeoIog...
# 919527                                                NaN
# 919528  [{'start': 3, 'end': 11, 'username': 'Irwanxq'...
#
#                                      entities.annotations  geo.place_id  \
# 0                                                     NaN           NaN
# 1                                                     NaN           NaN
# 2                                                     NaN           NaN
# 3                                                     NaN           NaN
# 4       [{'start': 71, 'end': 73, 'probability': 0.917...           NaN
# ...                                                   ...           ...
# 919524  [{'start': 22, 'end': 49, 'probability': 0.330...           NaN
# 919525  [{'start': 42, 'end': 47, 'probability': 0.848...           NaN
# 919526                                                NaN           NaN
# 919527                                                NaN           NaN
# 919528                                                NaN           NaN
#
#                                         entities.hashtags  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 919524            [{'start': 18, 'end': 21, 'tag': 'UK'}]
# 919525  [{'start': 170, 'end': 193, 'tag': 'Leadership...
# 919526                                                NaN
# 919527                                                NaN
# 919528                                                NaN
#
#        geo.coordinates.type geo.coordinates.coordinates entities.cashtags  \
# 0                       NaN                         NaN               NaN
# 1                       NaN                         NaN               NaN
# 2                       NaN                         NaN               NaN
# 3                       NaN                         NaN               NaN
# 4                       NaN                         NaN               NaN
# ...                     ...                         ...               ...
# 919524                  NaN                         NaN               NaN
# 919525                  NaN                         NaN               NaN
# 919526                  NaN                         NaN               NaN
# 919527                  NaN                         NaN               NaN
# 919528                  NaN                         NaN               NaN
#
#        withheld.copyright withheld.country_codes withheld.scope
# 0                     NaN                    NaN            NaN
# 1                     NaN                    NaN            NaN
# 2                     NaN                    NaN            NaN
# 3                     NaN                    NaN            NaN
# 4                     NaN                    NaN            NaN
# ...                   ...                    ...            ...
# 919524                NaN                    NaN            NaN
# 919525                NaN                    NaN            NaN
# 919526                NaN                    NaN            NaN
# 919527                NaN                    NaN            NaN
# 919528                NaN                    NaN            NaN
#
# [919529 rows x 24 columns]

# %% [markdown]
# ## Tweet DataFrame Modification (NLP)

# %%
TWEET_TOKENIZER = TweetTokenizer(preserve_case=False,
                                 strip_handles=True, reduce_len=False)
STOPWORDS = (set(nltk.corpus.stopwords.words("english")) |
             {"...", '…', '•', '’', "com"} |
             set(punctuation))

# Functions
# --- Replace URLs in `string` with text of `replacement`
def replace_urls(string, replacement=None):
    if replacement is None:
        replacement = "<-URL->"
    pattern = re.compile('(https?://)?(\w*[.]\w+)+([/?=&]+\w+)*')
    return re.sub(pattern, replacement, string)

# --- Tokenize text and remove punctuation/stopwords etc
def tokenizer(tweet_text, custom_words=None):
    text = (replace_urls(tweet_text))
    tokens = TWEET_TOKENIZER.tokenize(text.lower())
    tokens = (token for token in tokens if token not in punctuation)
    tokens = (token for token in tokens if token.islower())
    tokens = (token for token in tokens if token not in STOPWORDS)
    tokens = (token for token in tokens if len(token) >= 3)
    if custom_words:
        tokens = (token for token in tokens if token not in custom_words)
    return list(tokens)

# Main
df = df.assign(text_processed=df['text'].apply(lambda t: tokenizer(t)))
df
# Out:
#         in_reply_to_user_id lang                   id reply_settings  \
# 0       1021209821695991810   en  1079957943343144960       everyone
# 1        772925896130961408   en  1079957943334912000       everyone
# 2                       NaN   en  1079957943334899712       everyone
# 3                       NaN   en  1079957943330705409       everyone
# 4                       NaN   en  1079957943330627584       everyone
# ...                     ...  ...                  ...            ...
# 919524                  NaN   en  1437119038228926466       everyone
# 919525                  NaN   en  1437119038228865025       everyone
# 919526  1352321120368799852   en  1437119038224744449       everyone
# 919527                  NaN   en  1437119038220652551       everyone
# 919528                  NaN   en  1437119038220427264       everyone
#
#                                         referenced_tweets  \
# 0       [{'type': 'replied_to', 'id': '107995732227579...
# 1       [{'type': 'replied_to', 'id': '107995300863559...
# 2       [{'type': 'retweeted', 'id': '1079957890784481...
# 3       [{'type': 'retweeted', 'id': '1079280554560765...
# 4       [{'type': 'retweeted', 'id': '1079957919792353...
# ...                                                   ...
# 919524  [{'type': 'retweeted', 'id': '1437118272453885...
# 919525                                                NaN
# 919526  [{'type': 'replied_to', 'id': '143711889764425...
# 919527                                                NaN
# 919528  [{'type': 'retweeted', 'id': '1436988747254403...
#
#             conversation_id  \
# 0       1079710990441181185
# 1       1079953008635592704
# 2       1079957943334899712
# 3       1079957943330705409
# 4       1079957943330627584
# ...                     ...
# 919524  1437119038228926466
# 919525  1437119038228865025
# 919526  1437118897644257280
# 919527  1437119038220652551
# 919528  1437119038220427264
#
#                                                      text  \
# 0       @Panchin083 Hahahah i wuv you https://t.co/Z4H...
# 1       @ViciousRalph Why you doubt yourself? Figure o...
# 2       RT @tcm: Still struggling to find the perfect ...
# 3           RT @emilyxsnapp: fuck https://t.co/oBcfD6HPgj
# 4       RT @entwinedglobal: We wish you all a prospero...
# ...                                                   ...
# 919524  RT @EliseiNicole: #UK Manchester Parklife Fest...
# 919525  Yaqoob (ع) cried for 40 years even though Yous...
# 919526                @sopeoIogist outro  tear  is  yours
# 919527  Turn on Air-Con! The current temperature is 26...
# 919528  RT @Irwanxq: Dalam relationship ni tak perlu p...
#
#                       created_at            author_id  \
# 0      2019-01-01 04:30:12+00:00   989088763094732805
# 1      2019-01-01 04:30:12+00:00   954046885467246592
# 2      2019-01-01 04:30:12+00:00             28752714
# 3      2019-01-01 04:30:12+00:00            231199325
# 4      2019-01-01 04:30:12+00:00   809111804035104768
# ...                          ...                  ...
# 919524 2021-09-12 18:20:53+00:00            141679950
# 919525 2021-09-12 18:20:53+00:00           2199814184
# 919526 2021-09-12 18:20:53+00:00  1372615442993414144
# 919527 2021-09-12 18:20:53+00:00  1397006132460232705
# 919528 2021-09-12 18:20:53+00:00           1121296513
#
#                                             entities.urls  ...  \
# 0       [{'start': 30, 'end': 53, 'url': 'https://t.co...  ...
# 1                                                     NaN  ...
# 2                                                     NaN  ...
# 3       [{'start': 22, 'end': 45, 'url': 'https://t.co...  ...
# 4                                                     NaN  ...
# ...                                                   ...  ...
# 919524  [{'start': 80, 'end': 103, 'url': 'https://t.c...  ...
# 919525  [{'start': 194, 'end': 217, 'url': 'https://t....  ...
# 919526                                                NaN  ...
# 919527                                                NaN  ...
# 919528                                                NaN  ...
#
#                                      entities.annotations  geo.place_id  \
# 0                                                     NaN           NaN
# 1                                                     NaN           NaN
# 2                                                     NaN           NaN
# 3                                                     NaN           NaN
# 4       [{'start': 71, 'end': 73, 'probability': 0.917...           NaN
# ...                                                   ...           ...
# 919524  [{'start': 22, 'end': 49, 'probability': 0.330...           NaN
# 919525  [{'start': 42, 'end': 47, 'probability': 0.848...           NaN
# 919526                                                NaN           NaN
# 919527                                                NaN           NaN
# 919528                                                NaN           NaN
#
#                                         entities.hashtags  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 919524            [{'start': 18, 'end': 21, 'tag': 'UK'}]
# 919525  [{'start': 170, 'end': 193, 'tag': 'Leadership...
# 919526                                                NaN
# 919527                                                NaN
# 919528                                                NaN
#
#         geo.coordinates.type geo.coordinates.coordinates entities.cashtags  \
# 0                        NaN                         NaN               NaN
# 1                        NaN                         NaN               NaN
# 2                        NaN                         NaN               NaN
# 3                        NaN                         NaN               NaN
# 4                        NaN                         NaN               NaN
# ...                      ...                         ...               ...
# 919524                   NaN                         NaN               NaN
# 919525                   NaN                         NaN               NaN
# 919526                   NaN                         NaN               NaN
# 919527                   NaN                         NaN               NaN
# 919528                   NaN                         NaN               NaN
#
#        withheld.copyright withheld.country_codes withheld.scope  \
# 0                     NaN                    NaN            NaN
# 1                     NaN                    NaN            NaN
# 2                     NaN                    NaN            NaN
# 3                     NaN                    NaN            NaN
# 4                     NaN                    NaN            NaN
# ...                   ...                    ...            ...
# 919524                NaN                    NaN            NaN
# 919525                NaN                    NaN            NaN
# 919526                NaN                    NaN            NaN
# 919527                NaN                    NaN            NaN
# 919528                NaN                    NaN            NaN
#
#                                            text_processed
# 0                                 [hahahah, wuv, <-url->]
# 1       [doubt, figure, need, work, better, keep, head...
# 2       [still, struggling, find, perfect, cocktail, r...
# 3                                         [fuck, <-url->]
# 4       [wish, prosperous, new, year, full, god's, ble...
# ...                                                   ...
# 919524  [#uk, manchester, parklife, festival, <-url->,...
# 919525  [yaqoob, cried, years, even, though, yousuf, a...
# 919526                                      [outro, tear]
# 919527  [turn, air-con, current, temperature, <-url->,...
# 919528  [dalam, relationship, tak, perlu, paksa, laran...
#
# [919529 rows x 25 columns]

# %% [markdown]
# ## Save DataFrame

# %%
df.to_pickle('Your/Data/Path/sample_dataframe.pkl')
